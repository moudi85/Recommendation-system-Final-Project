# %%
from __future__ import print_function    # (at top of module)
import requests
from furl import furl
from math import ceil
# %matplotlib inline
from IPython.display import Image 
import matplotlib.pyplot as plt
import time
import timeit
import pandas as pd
import numpy as np
import re
import spotipy
import sys
import os
import json
import pprint
import seaborn as sns
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy.oauth2 as oauth2
import spotipy.util as util
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %% [markdown]
# <h1>- Acquire the Data

# %% [markdown]
# ## Spotify Api Auth

# %%
cid ="ae0dc287abd746f9bfc9fabb30966d0c" 
secret = "40c2e16da28c49e1839219c99e697910"
username= "Mohamad Eldebek"

client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

artist_name = []
track_name = []
track_id = [] 
popularity = []
album_name = []


for i in range(0,10000,50):
    track_results = sp.search(q='year:2018', type='track', limit=50,offset=i)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        album_name.append(t['album']['name'])

# %%
track_results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=year%3A2018&type=track&offset=9950&limit=50',
#   'items': [{'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3zz0C9ZwusoYHsr5K8b0HW'},
#        'href': 'https://api.spotify.com/v1/artists/3zz0C9ZwusoYHsr5K8b0HW',
#        'id': '3zz0C9ZwusoYHsr5K8b0HW',
#        'name': 'Alec Windt',
#        'type': 'artist',
#        'uri': 'spotify:artist:3zz0C9ZwusoYHsr5K8b0HW'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2KlIpwlJnD92CbIQp3CiIm'},
#      'href': 'https://api.spotify.com/v1/albums/2KlIpwlJnD92CbIQp3CiIm',
#      'id': '2KlIpwlJnD92CbIQp3CiIm',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/77eb7c17cafe550394c84966ae196b21e5819582',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/77eb7c17cafe5502877b625b571674bd8e82cb0a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/77eb7c17cafe5501613373ebe586a95d33109391',
#        'width': 64}],
#      'name': 'In Love',
#      'release_date': '2018-11-26',
#      'release_date_precision': 'day',
#      'total_tracks': 2,
#      'type': 'album',
#      'uri': 'spotify:album:2KlIpwlJnD92CbIQp3CiIm'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3zz0C9ZwusoYHsr5K8b0HW'},
#       'href': 'https://api.spotify.com/v1/artists/3zz0C9ZwusoYHsr5K8b0HW',
#       'id': '3zz0C9ZwusoYHsr5K8b0HW',
#       'name': 'Alec Windt',
#       'type': 'artist',
#       'uri': 'spotify:artist:3zz0C9ZwusoYHsr5K8b0HW'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 116268,
#     'explicit': False,
#     'external_ids': {'isrc': 'SE5IB1800953'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2bUMk8naDcabvgipR14U22'},
#     'href': 'https://api.spotify.com/v1/tracks/2bUMk8naDcabvgipR14U22',
#     'id': '2bUMk8naDcabvgipR14U22',
#     'is_local': False,
#     'name': 'In Love',
#     'popularity': 53,
#     'preview_url': 'https://p.scdn.co/mp3-preview/2b33ead25f9cd98090e4fe896d9348ed97788c88?cid=ae0dc287abd746f9bfc9fabb30966d0c',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2bUMk8naDcabvgipR14U22'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/10Z7WzKMeIdNBKexi1YarP'},
#        'href': 'https://api.spotify.com/v1/artists/10Z7WzKMeIdNBKexi1YarP',
#        'id': '10Z7WzKMeIdNBKexi1YarP',
#        'name': 'Fame on Fire',
#        'type': 'artist',
#        'uri': 'spotify:artist:10Z7WzKMeIdNBKexi1YarP'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0UzEblTiStIxPCLPAUZYfP'},
#      'href': 'https://api.spotify.com/v1/albums/0UzEblTiStIxPCLPAUZYfP',
#      'id': '0UzEblTiStIxPCLPAUZYfP',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/89058de7d47fa09d5be310b5dd51414167ba2db8',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/577a1a3e02e3eaef280f919f9ad5c42387c3cb3a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/4f4bd79f4e9690daee57b8ab6ded0486657e08f2',
#        'width': 64}],
#      'name': 'Happier',
#      'release_date': '2018-12-20',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:0UzEblTiStIxPCLPAUZYfP'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/10Z7WzKMeIdNBKexi1YarP'},
#       'href': 'https://api.spotify.com/v1/artists/10Z7WzKMeIdNBKexi1YarP',
#       'id': '10Z7WzKMeIdNBKexi1YarP',
#       'name': 'Fame on Fire',
#       'type': 'artist',
#       'uri': 'spotify:artist:10Z7WzKMeIdNBKexi1YarP'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 211800,
#     'explicit': False,
#     'external_ids': {'isrc': 'TCADZ1890713'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4FmPj02iuWprAX13oZq4MN'},
#     'href': 'https://api.spotify.com/v1/tracks/4FmPj02iuWprAX13oZq4MN',
#     'id': '4FmPj02iuWprAX13oZq4MN',
#     'is_local': False,
#     'name': 'Happier',
#     'popularity': 49,
#     'preview_url': 'https://p.scdn.co/mp3-preview/bac5970ee9cb5246318cbd1d1cf7525d66d7ec7e?cid=ae0dc287abd746f9bfc9fabb30966d0c',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:4FmPj02iuWprAX13oZq4MN'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1xD85sp0kecIVuMwUHShxs'},
#        'href': 'https://api.spotify.com/v1/artists/1xD85sp0kecIVuMwUHShxs',
#        'id': '1xD85sp0kecIVuMwUHShxs',
#        'name': 'Twin Peaks',
#        'type': 'artist',
#        'uri': 'spotify:artist:1xD85sp0kecIVuMwUHShxs'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/27kop3lqGhtX1fQsBc0lty'},
#      'href': 'https://api.spotify.com/v1/albums/27kop3lqGhtX1fQsBc0lty',
#      'id': '27kop3lqGhtX1fQsBc0lty',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/69387e6a06a60231308f8c03af6bb6efd767c7d0',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/af141e3d09c1ac1dce9622ee2334ecbd2a3a2617',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/3a5eade61da9b5a2df3aa0b58bb79d6010862639',
#        'width': 64}],
#      'name': "Sweet '17 Singles",
#      'release_date': '2018-02-09',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:27kop3lqGhtX1fQsBc0lty'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1xD85sp0kecIVuMwUHShxs'},
#       'href': 'https://api.spotify.com/v1/artists/1xD85sp0kecIVuMwUHShxs',
#       'id': '1xD85sp0kecIVuMwUHShxs',
#       'name': 'Twin Peaks',
#       'type': 'artist',
#       'uri': 'spotify:artist:1xD85sp0kecIVuMwUHShxs'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 215687,
#     'explicit': False,
#     'external_ids': {'isrc': 'QM5BK1700158'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/71gZOVZcfn2Yp6evM2PdzW'},
#     'href': 'https://api.spotify.com/v1/tracks/71gZOVZcfn2Yp6evM2PdzW',
#     'id': '71gZOVZcfn2Yp6evM2PdzW',
#     'is_local': False,
#     'name': 'Shake Your Lonely',
#     'popularity': 47,
#     'preview_url': 'https://p.scdn.co/mp3-preview/800b80c4329b8f93acf31411a18646f8e7aacbe8?cid=ae0dc287abd746f9bfc9fabb30966d0c',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:71gZOVZcfn2Yp6evM2PdzW'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4DSNcg40nf6T3eNAObq1Lo'},
#        'href': 'https://api.spotify.com/v1/artists/4DSNcg40nf6T3eNAObq1Lo',
#        'id': '4DSNcg40nf6T3eNAObq1Lo',
#        'name': 'The Browning',
#        'type': 'artist',
#        'uri': 'spotify:artist:4DSNcg40nf6T3eNAObq1Lo'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0tWTECHIh3CxohEXcWJF9k'},
#      'href': 'https://api.spotify.com/v1/albums/0tWTECHIh3CxohEXcWJF9k',
#      'id': '0tWTECHIh3CxohEXcWJF9k',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/49a3480e24033196d627c37c8ebb43f3269d9bfe',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab741f0f67d669b555880a11f55cb812a5055963',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/de1c5bcfd4ccc6545f253281d7a81546a89ca1e9',
#        'width': 64}],
#      'name': 'Geist',
#      'release_date': '2018-10-26',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:0tWTECHIh3CxohEXcWJF9k'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4DSNcg40nf6T3eNAObq1Lo'},
#       'href': 'https://api.spotify.com/v1/artists/4DSNcg40nf6T3eNAObq1Lo',
#       'id': '4DSNcg40nf6T3eNAObq1Lo',
#       'name': 'The Browning',
#       'type': 'artist',
#       'uri': 'spotify:artist:4DSNcg40nf6T3eNAObq1Lo'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 184000,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBUM71803961'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3AoODWFmosarxlZnX2dyOe'},
#     'href': 'https://api.spotify.com/v1/tracks/3AoODWFmosarxlZnX2dyOe',
#     'id': '3AoODWFmosarxlZnX2dyOe',
#     'is_local': False,
#     'name': 'Carnage',
#     'popularity': 49,
#     'preview_url': None,
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:3AoODWFmosarxlZnX2dyOe'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0ubGY2CcC0tvR0eE6hJaT8'},
#        'href': 'https://api.spotify.com/v1/artists/0ubGY2CcC0tvR0eE6hJaT8',
#        'id': '0ubGY2CcC0tvR0eE6hJaT8',
#        'name': 'Charlie Burg',
#        'type': 'artist',
#        'uri': 'spotify:artist:0ubGY2CcC0tvR0eE6hJaT8'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/30r4Mfu3B8LIYU0hyfzG0r'},
#      'href': 'https://api.spotify.com/v1/albums/30r4Mfu3B8LIYU0hyfzG0r',
#      'id': '30r4Mfu3B8LIYU0hyfzG0r',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/5dd37bc4dfbf50cbd3e3d1a7482355f075f391d0',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/f92b973540e38f6c90b2963b8691a0e7504655a6',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/299a2b2f0a126f962c787139d49c9803c07f50ec',
#        'width': 64}],
#      'name': 'PlantedInMyMind.Memo',
#      'release_date': '2018-01-30',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:30r4Mfu3B8LIYU0hyfzG0r'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0ubGY2CcC0tvR0eE6hJaT8'},
#       'href': 'https://api.spotify.com/v1/artists/0ubGY2CcC0tvR0eE6hJaT8',
#       'id': '0ubGY2CcC0tvR0eE6hJaT8',
#       'name': 'Charlie Burg',
#       'type': 'artist',
#       'uri': 'spotify:artist:0ubGY2CcC0tvR0eE6hJaT8'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 89072,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZAPG1892033'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4osxJNBTFLCMUhXThxGClU'},
#     'href': 'https://api.spotify.com/v1/tracks/4osxJNBTFLCMUhXThxGClU',
#     'id': '4osxJNBTFLCMUhXThxGClU',
#     'is_local': False,
#     'name': 'PlantedInMyMind.Memo',
#     'popularity': 49,
#     'preview_url': 'https://p.scdn.co/mp3-preview/b9af6c63719774f98201ba6794373c43d6eff04c?cid=ae0dc287abd746f9bfc9fabb30966d0c',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:4osxJNBTFLCMUhXThxGClU'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6In7t4xPMNmmVOewOXS6Yb'},
#        'href': 'https://api.spotify.com/v1/artists/6In7t4xPMNmmVOewOXS6Yb',
#        'id': '6In7t4xPMNmmVOewOXS6Yb',
#        'name': 'Mefree',
#        'type': 'artist',
#        'uri': 'spotify:artist:6In7t4xPMNmmVOewOXS6Yb'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3cTaaGetEBEQiozi50SzwQ'},
#      'href': 'https://api.spotify.com/v1/albums/3cTaaGetEBEQiozi50SzwQ',
#      'id': '3cTaaGetEBEQiozi50SzwQ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/be344cd06048374119343e6b6b40ab84d8149e4d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/33bd321c2812310247d82839824d789b9929a254',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/5a9774f16d40eb05f7a7b2fc127a6eb26c868180',
#        'width': 64}],
#      'name': 'Perfect Start',
#      'release_date': '2018-07-13',
#      'release_date_precision': 'day',
#      'total_tracks': 4,
#      'type': 'album',
#      'uri': 'spotify:album:3cTaaGetEBEQiozi50SzwQ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6In7t4xPMNmmVOewOXS6Yb'},
#       'href': 'https://api.spotify.com/v1/artists/6In7t4xPMNmmVOewOXS6Yb',
#       'id': '6In7t4xPMNmmVOewOXS6Yb',
#       'name': 'Mefree',
#       'type': 'artist',
#       'uri': 'spotify:artist:6In7t4xPMNmmVOewOXS6Yb'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 222641,
#     'explicit': False,
#     'external_ids': {'isrc': 'SE5Q51800678'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1emNwBhNQrNofoHrlDEndw'},
#     'href': 'https://api.spotify.com/v1/tracks/1emNwBhNQrNofoHrlDEndw',
#     'id': '1emNwBhNQrNofoHrlDEndw',
#     'is_local': False,
#     'name': 'Horizons',
#     'popularity': 59,
#     'preview_url': 'https://p.scdn.co/mp3-preview/891c82d0f8e6d2d185cc95412a4c14f814573b2a?cid=ae0dc287abd746f9bfc9fabb30966d0c',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:1emNwBhNQrNofoHrlDEndw'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/69GGBxA162lTqCwzJG5jLp'},
#        'href': 'https://api.spotify.com/v1/artists/69GGBxA162lTqCwzJG5jLp',
#        'id': '69GGBxA162lTqCwzJG5jLp',
#        'name': 'The Chainsmokers',
#        'type': 'artist',
#        'uri': 'spotify:artist:69GGBxA162lTqCwzJG5jLp'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4dZcaaBx14iVnPETVFz4qj'},
#      'href': 'https://api.spotify.com/v1/albums/4dZcaaBx14iVnPETVFz4qj',
#      'id': '4dZcaaBx14iVnPETVFz4qj',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/b7cd9e9c79c83ede361bcc06f9f0c77da15b9046',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/6691d0570e2c1f5de3be02d826967df63fbb196d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/abcd55cbd93d9a41428ad0e6babab3b6b3acf2ce',
#        'width': 64}],
#      'name': 'Beach House (Ashworth Remix)',
#      'release_date': '2018-12-08',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:4dZcaaBx14iVnPETVFz4qj'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/69GGBxA162lTqCwzJG5jLp'},
#       'href': 'https://api.spotify.com/v1/artists/69GGBxA162lTqCwzJG5jLp',
#       'id': '69GGBxA162lTqCwzJG5jLp',
#       'name': 'The Chainsmokers',
#       'type': 'artist',
#       'uri': 'spotify:artist:69GGBxA162lTqCwzJG5jLp'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3pcGjcfEW3YD2Hfk6tDR5S'},
#       'href': 'https://api.spotify.com/v1/artists/3pcGjcfEW3YD2Hfk6tDR5S',
#       'id': '3pcGjcfEW3YD2Hfk6tDR5S',
#       'name': 'Ashworth',
#       'type': 'artist',
#       'uri': 'spotify:artist:3pcGjcfEW3YD2Hfk6tDR5S'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 204453,
#     'explicit': False,
#     'external_ids': {'isrc': 'USQX91803652'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5tjpOTsbVVbqWRQuymGnuy'},
#     'href': 'https://api.spotify.com/v1/tracks/5tjpOTsbVVbqWRQuymGnuy',
#     'id': '5tjpOTsbVVbqWRQuymGnuy',
#     'is_local': False,
#     'name': 'Beach House - Ashworth Remix',
#     'popularity': 54,
#     'preview_url': 'https://p.scdn.co/mp3-preview/31682fdc9aa889752767533d1c7acf65cf9b10ef?cid=ae0dc287abd746f9bfc9fabb30966d0c',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:5tjpOTsbVVbqWRQuymGnuy'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6UBA15slIuadJ8h2lPRPos'},
#        'href': 'https://api.spotify.com/v1/artists/6UBA15slIuadJ8h2lPRPos',
#        'id': '6UBA15slIuadJ8h2lPRPos',
#        'name': 'Tech N9ne',
#        'type': 'artist',
#        'uri': 'spotify:artist:6UBA15slIuadJ8h2lPRPos'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6WG1LSZbJCwtGIuaGB0UUi'},
#      'href': 'https://api.spotify.com/v1/albums/6WG1LSZbJCwtGIuaGB0UUi',
#      'id': '6WG1LSZbJCwtGIuaGB0UUi',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/e2897a142467b4973b77237b25c80e921970d05a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/45196313b267597474618279bd03f06482c055d1',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/fefb7ee8418d8a902148d78fdef7a2b812247ba7',
#        'width': 64}],
#      'name': 'Planet (Deluxe Edition)',
#      'release_date': '2018-03-02',
#      'release_date_precision': 'day',
#      'total_tracks': 19,
#      'type': 'album',
#      'uri': 'spotify:album:6WG1LSZbJCwtGIuaGB0UUi'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6UBA15slIuadJ8h2lPRPos'},
#       'href': 'https://api.spotify.com/v1/artists/6UBA15slIuadJ8h2lPRPos',
#       'id': '6UBA15slIuadJ8h2lPRPos',
#       'name': 'Tech N9ne',
#       'type': 'artist',
#       'uri': 'spotify:artist:6UBA15slIuadJ8h2lPRPos'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 187295,
#     'explicit': True,
#     'external_ids': {'isrc': 'USZHR1800003'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4ahl4meq4Y4L3bNa3fHQ1e'},
#     'href': 'https://api.spotify.com/v1/tracks/4ahl4meq4Y4L3bNa3fHQ1e',
#     'id': '4ahl4meq4Y4L3bNa3fHQ1e',
#     'is_local': False,
#     'name': 'Kick It With Myself',
#     'popularity': 46,
#     'preview_url': 'https://p.scdn.co/mp3-preview/6e8eafab4dee7a6c2b4a5f0c0753187d233473b4?cid=ae0dc287abd746f9bfc9fabb30966d0c',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:4ahl4meq4Y4L3bNa3fHQ1e'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Q9nxD19emMUTTWtFi7jZc'},
#        'href': 'https://api.spotify.com/v1/artists/1Q9nxD19emMUTTWtFi7jZc',
#        'id': '1Q9nxD19emMUTTWtFi7jZc',
#        'name': 'The Afters',
#        'type': 'artist',
#        'uri': 'spotify:artist:1Q9nxD19emMUTTWtFi7jZc'}],
#      'available_markets': ['CA', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/30Cu7H7abvkKw8EuWckmG0'},
#      'href': 'https://api.spotify.com/v1/albums/30Cu7H7abvkKw8EuWckmG0',
#      'id': '30Cu7H7abvkKw8EuWckmG0',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/f4a768623663fcfec1d4ab1eac48ac5ac5f39c39',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/07eaa63b441e1a4988503cb6687fcd9591304871',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/dcdb221895ef91607bdd32614c3b7cd8f7a4ab7f',
#        'width': 64}],
#      'name': 'The Beginning & Everything After',
#      'release_date': '2018-11-02',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:30Cu7H7abvkKw8EuWckmG0'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Q9nxD19emMUTTWtFi7jZc'},
#       'href': 'https://api.spotify.com/v1/artists/1Q9nxD19emMUTTWtFi7jZc',
#       'id': '1Q9nxD19emMUTTWtFi7jZc',
#       'name': 'The Afters',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Q9nxD19emMUTTWtFi7jZc'}],
#     'available_markets': ['CA', 'US'],
#     'disc_number': 1,
#     'duration_ms': 202480,
#     'explicit': False,
#     'external_ids': {'isrc': 'USM2C1801302'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7IKh3MlTFsgFOaqKc0z7If'},
#     'href': 'https://api.spotify.com/v1/tracks/7IKh3MlTFsgFOaqKc0z7If',
#     'id': '7IKh3MlTFsgFOaqKc0z7If',
#     'is_local': False,
#     'name': 'I Will Fear No More',
#     'popularity': 45,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a9cb8afbd578d99c1f8aebd2afa85fc8443ec6ef?cid=ae0dc287abd746f9bfc9fabb30966d0c',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:7IKh3MlTFsgFOaqKc0z7If'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2QMsj4XJ7ne2hojxt6v5eb'},
#        'href': 'https://api.spotify.com/v1/artists/2QMsj4XJ7ne2hojxt6v5eb',
#        'id': '2QMsj4XJ7ne2hojxt6v5eb',
#        'name': 'Riley Green',
#        'type': 'artist',
#        'uri': 'spotify:artist:2QMsj4XJ7ne2hojxt6v5eb'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5o7GKDnohqZemm2TLISlru'},
#      'href': 'https://api.spotify.com/v1/albums/5o7GKDnohqZemm2TLISlru',
#      'id': '5o7GKDnohqZemm2TLISlru',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/2e20ab9ac53f42f9a303c10a8b5d13ec256a1a17',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/31bc80ad1388fda2d5f7bd12933f0ab6111617e1',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/0dca51fd8f07e94ad7780ec639b7f5afd685edc0',
#        'width': 64}],
#      'name': 'County Line',
#      'release_date': '2018-06-01',
#      'release_date_precision': 'day',
#      'total_tracks': 5,
#      'type': 'album',
#      'uri': 'spotify:album:5o7GKDnohqZemm2TLISlru'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2QMsj4XJ7ne2hojxt6v5eb'},
#       'href': 'https://api.spotify.com/v1/artists/2QMsj4XJ7ne2hojxt6v5eb',
#       'id': '2QMsj4XJ7ne2hojxt6v5eb',
#       'name': 'Riley Green',
#       'type': 'artist',
#       'uri': 'spotify:artist:2QMsj4XJ7ne2hojxt6v5eb'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 172330,
#     'explicit': False,
#     'external_ids': {'isrc': 'TCACM1607334'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7JJyuNGhAiPO1UHZcMITd8'},
#     'href': 'https://api.spotify.com/v1/tracks/7JJyuNGhAiPO1UHZcMITd8',
#     'id': '7JJyuNGhAiPO1UHZcMITd8',
#     'is_local': False,
#     'name': 'Play Her Tonight',
#     'popularity': 45,
#     'preview_url': None,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:7JJyuNGhAiPO1UHZcMITd8'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1vyhD5VmyZ7KMfW5gqLgo5'},
#        'href': 'https://api.spotify.com/v1/artists/1vyhD5VmyZ7KMfW5gqLgo5',
#        'id': '1vyhD5VmyZ7KMfW5gqLgo5',
#        'name': 'J Balvin',
#        'type': 'artist',
#        'uri': 'spotify:artist:1vyhD5VmyZ7KMfW5gqLgo5'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5kprdYds6oZb4iSldfflOT'},
#      'href': 'https://api.spotify.com/v1/albums/5kprdYds6oZb4iSldfflOT',
#      'id': '5kprdYds6oZb4iSldfflOT',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/cc56f48efc4285caaa8e895337846f5174bf3989',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/7fc77d0d78cee3538bf6843cf01463d5d7b59acb',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/5cbecd0922be98dad9bbb23fc1ff46438a671102',
#        'width': 64}],
#      'name': 'Vibras',
#      'release_date': '2018-05-25',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:5kprdYds6oZb4iSldfflOT'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1vyhD5VmyZ7KMfW5gqLgo5'},
#       'href': 'https://api.spotify.com/v1/artists/1vyhD5VmyZ7KMfW5gqLgo5',
#       'id': '1vyhD5VmyZ7KMfW5gqLgo5',
#       'name': 'J Balvin',
#       'type': 'artist',
#       'uri': 'spotify:artist:1vyhD5VmyZ7KMfW5gqLgo5'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0XK6kT7xcZAlcYrNjOgzJe'},
#       'href': 'https://api.spotify.com/v1/artists/0XK6kT7xcZAlcYrNjOgzJe',
#       'id': '0XK6kT7xcZAlcYrNjOgzJe',
#       'name': 'Carla Morrison',
#       'type': 'artist',
#       'uri': 'spotify:artist:0XK6kT7xcZAlcYrNjOgzJe'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 66226,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71802249'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2EEjiKbE4pAjX49TrBzw1X'},
#     'href': 'https://api.spotify.com/v1/tracks/2EEjiKbE4pAjX49TrBzw1X',
#     'id': '2EEjiKbE4pAjX49TrBzw1X',
#     'is_local': False,
#     'name': 'Vibras',
#     'popularity': 54,
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2EEjiKbE4pAjX49TrBzw1X'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3tqosLbNFNekyZyO2KJ6qd'},
#        'href': 'https://api.spotify.com/v1/artists/3tqosLbNFNekyZyO2KJ6qd',
#        'id': '3tqosLbNFNekyZyO2KJ6qd',
#        'name': 'Mike Sherm',
#        'type': 'artist',
#        'uri': 'spotify:artist:3tqosLbNFNekyZyO2KJ6qd'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/47r14uxDMJCVQsCLfzE2lP'},
#      'href': 'https://api.spotify.com/v1/albums/47r14uxDMJCVQsCLfzE2lP',
#      'id': '47r14uxDMJCVQsCLfzE2lP',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/7a614ec36eb55be309ec91924c41566b03e83fd4',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/e8776ee89311eb057e0d91980f9d9414c1733c90',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/b4cc7633829552802952c89c190cd527eef1cf27',
#        'width': 64}],
#      'name': 'Born a Boss',
#      'release_date': '2018-08-16',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:47r14uxDMJCVQsCLfzE2lP'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3tqosLbNFNekyZyO2KJ6qd'},
#       'href': 'https://api.spotify.com/v1/artists/3tqosLbNFNekyZyO2KJ6qd',
#       'id': '3tqosLbNFNekyZyO2KJ6qd',
#       'name': 'Mike Sherm',
#       'type': 'artist',
#       'uri': 'spotify:artist:3tqosLbNFNekyZyO2KJ6qd'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 149482,
#     'explicit': True,
#     'external_ids': {'isrc': 'TCADU1805414'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3jICYNwx4YbaMsC7I8AuEA'},
#     'href': 'https://api.spotify.com/v1/tracks/3jICYNwx4YbaMsC7I8AuEA',
#     'id': '3jICYNwx4YbaMsC7I8AuEA',
#     'is_local': False,
#     'name': 'Born a Boss',
#     'popularity': 45,
#     'preview_url': 'https://p.scdn.co/mp3-preview/42ecf6917c33be767c6b989fdc02a7f4a631af1c?cid=ae0dc287abd746f9bfc9fabb30966d0c',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3jICYNwx4YbaMsC7I8AuEA'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/610EjgFatGvVPtib97jQ8G'},
#        'href': 'https://api.spotify.com/v1/artists/610EjgFatGvVPtib97jQ8G',
#        'id': '610EjgFatGvVPtib97jQ8G',
#        'name': 'NEEDTOBREATHE',
#        'type': 'artist',
#        'uri': 'spotify:artist:610EjgFatGvVPtib97jQ8G'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6JjEopFCXCRvPaD6W12GfQ'},
#      'href': 'https://api.spotify.com/v1/albums/6JjEopFCXCRvPaD6W12GfQ',
#      'id': '6JjEopFCXCRvPaD6W12GfQ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/9041156f9c99353fbab6fdd45f3d28fad3cb8039',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/43e989a06f73d47cb34a356b517f3f5591d2f6cf',
# ...
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:507UUx311ghfFTMSuHUeyS'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7GJbWH8vhhuW22707B8HsW'},
#        'href': 'https://api.spotify.com/v1/artists/7GJbWH8vhhuW22707B8HsW',
#        'id': '7GJbWH8vhhuW22707B8HsW',
#        'name': 'Thirdstory',
#        'type': 'artist',
#        'uri': 'spotify:artist:7GJbWH8vhhuW22707B8HsW'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3UJW1p1qiGScFrGKLwBptB'},
#      'href': 'https://api.spotify.com/v1/albums/3UJW1p1qiGScFrGKLwBptB',
#      'id': '3UJW1p1qiGScFrGKLwBptB',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/fa3fb29507d0453232aa4f72eef1d6208558f3c1',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/af132b8ffcab460d1a5f513db3411dae3761ab41',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/6c1e0d3af346a9b5b8d3cf8b6ecba190ebd0f1fe',
#        'width': 64}],
#      'name': 'Cold Heart',
#      'release_date': '2018-03-09',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:3UJW1p1qiGScFrGKLwBptB'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7GJbWH8vhhuW22707B8HsW'},
#       'href': 'https://api.spotify.com/v1/artists/7GJbWH8vhhuW22707B8HsW',
#       'id': '7GJbWH8vhhuW22707B8HsW',
#       'name': 'Thirdstory',
#       'type': 'artist',
#       'uri': 'spotify:artist:7GJbWH8vhhuW22707B8HsW'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 206440,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71714159'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6Zu27PkzMSe2oL9kgCXyk3'},
#     'href': 'https://api.spotify.com/v1/tracks/6Zu27PkzMSe2oL9kgCXyk3',
#     'id': '6Zu27PkzMSe2oL9kgCXyk3',
#     'is_local': False,
#     'name': 'Still In Love',
#     'popularity': 48,
#     'preview_url': None,
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:6Zu27PkzMSe2oL9kgCXyk3'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5yCOPpDHEQxwSJJL2LAqLj'},
#        'href': 'https://api.spotify.com/v1/artists/5yCOPpDHEQxwSJJL2LAqLj',
#        'id': '5yCOPpDHEQxwSJJL2LAqLj',
#        'name': 'Mack Brock',
#        'type': 'artist',
#        'uri': 'spotify:artist:5yCOPpDHEQxwSJJL2LAqLj'}],
#      'available_markets': ['AD',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'EC',
#       'EE',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JP',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'RO',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6zCU9zG1tIfA9V1UEfSPsz'},
#      'href': 'https://api.spotify.com/v1/albums/6zCU9zG1tIfA9V1UEfSPsz',
#      'id': '6zCU9zG1tIfA9V1UEfSPsz',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/0d7b40ec00ca2664c05b15e831a3fc974e009fc0',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/b47efbfaff735545b25994f115f690a80f8507b1',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/1dd50085d39283c181027f5e569c3b370966a546',
#        'width': 64}],
#      'name': 'Greater Things',
#      'release_date': '2018-09-14',
#      'release_date_precision': 'day',
#      'total_tracks': 9,
#      'type': 'album',
#      'uri': 'spotify:album:6zCU9zG1tIfA9V1UEfSPsz'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5yCOPpDHEQxwSJJL2LAqLj'},
#       'href': 'https://api.spotify.com/v1/artists/5yCOPpDHEQxwSJJL2LAqLj',
#       'id': '5yCOPpDHEQxwSJJL2LAqLj',
#       'name': 'Mack Brock',
#       'type': 'artist',
#       'uri': 'spotify:artist:5yCOPpDHEQxwSJJL2LAqLj'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JP',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'RO',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 307026,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71810812'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1GQsaKKI0ZJJPI5Zsop20u'},
#     'href': 'https://api.spotify.com/v1/tracks/1GQsaKKI0ZJJPI5Zsop20u',
#     'id': '1GQsaKKI0ZJJPI5Zsop20u',
#     'is_local': False,
#     'name': 'Christ Is Risen',
#     'popularity': 48,
#     'preview_url': None,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:1GQsaKKI0ZJJPI5Zsop20u'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3wjluyWXDHiiMKxkhaW1em'},
#        'href': 'https://api.spotify.com/v1/artists/3wjluyWXDHiiMKxkhaW1em',
#        'id': '3wjluyWXDHiiMKxkhaW1em',
#        'name': 'BoTalks',
#        'type': 'artist',
#        'uri': 'spotify:artist:3wjluyWXDHiiMKxkhaW1em'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1dG5X3Yj0RiXXs5xo3Y4d2'},
#      'href': 'https://api.spotify.com/v1/albums/1dG5X3Yj0RiXXs5xo3Y4d2',
#      'id': '1dG5X3Yj0RiXXs5xo3Y4d2',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/53da9adb39d75c1b09965c0d962b5afc2858cdc0',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/5d76aee021558730cd689618149fbe11fd4f93c2',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/a3eec7fc9774a7dc8d716c89d23eba7796a69e19',
#        'width': 64}],
#      'name': 'Fuck It',
#      'release_date': '2018-03-08',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:1dG5X3Yj0RiXXs5xo3Y4d2'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3wjluyWXDHiiMKxkhaW1em'},
#       'href': 'https://api.spotify.com/v1/artists/3wjluyWXDHiiMKxkhaW1em',
#       'id': '3wjluyWXDHiiMKxkhaW1em',
#       'name': 'BoTalks',
#       'type': 'artist',
#       'uri': 'spotify:artist:3wjluyWXDHiiMKxkhaW1em'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0cZPTEmf3mlwj5kjVXR4po'},
#       'href': 'https://api.spotify.com/v1/artists/0cZPTEmf3mlwj5kjVXR4po',
#       'id': '0cZPTEmf3mlwj5kjVXR4po',
#       'name': 'Caroline Pennell',
#       'type': 'artist',
#       'uri': 'spotify:artist:0cZPTEmf3mlwj5kjVXR4po'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 240299,
#     'explicit': True,
#     'external_ids': {'isrc': 'USA2P1811909'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1kvKOGxYFufFOZFEOCDJxz'},
#     'href': 'https://api.spotify.com/v1/tracks/1kvKOGxYFufFOZFEOCDJxz',
#     'id': '1kvKOGxYFufFOZFEOCDJxz',
#     'is_local': False,
#     'name': 'Fuck It',
#     'popularity': 50,
#     'preview_url': 'https://p.scdn.co/mp3-preview/dabc3644d07115cdbac4df0aae6e17efd85dfb55?cid=ae0dc287abd746f9bfc9fabb30966d0c',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1kvKOGxYFufFOZFEOCDJxz'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6ghiFYcwn2Vzl6K50U0UPz'},
#        'href': 'https://api.spotify.com/v1/artists/6ghiFYcwn2Vzl6K50U0UPz',
#        'id': '6ghiFYcwn2Vzl6K50U0UPz',
#        'name': 'Michael Ray',
#        'type': 'artist',
#        'uri': 'spotify:artist:6ghiFYcwn2Vzl6K50U0UPz'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4xb3GQ3k8DQRnfqvAar0pu'},
#      'href': 'https://api.spotify.com/v1/albums/4xb3GQ3k8DQRnfqvAar0pu',
#      'id': '4xb3GQ3k8DQRnfqvAar0pu',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/b40d9376b4ed22fd81c0808d5e08db5af87a33c2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/5ed4c01c1550f62b9c0e0814e2ea387d6f7a64f6',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/5336586b6d414f1d128bc2821daeec9459e0ce01',
#        'width': 64}],
#      'name': 'Amos',
#      'release_date': '2018-06-01',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:4xb3GQ3k8DQRnfqvAar0pu'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6ghiFYcwn2Vzl6K50U0UPz'},
#       'href': 'https://api.spotify.com/v1/artists/6ghiFYcwn2Vzl6K50U0UPz',
#       'id': '6ghiFYcwn2Vzl6K50U0UPz',
#       'name': 'Michael Ray',
#       'type': 'artist',
#       'uri': 'spotify:artist:6ghiFYcwn2Vzl6K50U0UPz'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 210680,
#     'explicit': False,
#     'external_ids': {'isrc': 'USWB11800703'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/48VOhlpXMX2a0u2IDMEbtd'},
#     'href': 'https://api.spotify.com/v1/tracks/48VOhlpXMX2a0u2IDMEbtd',
#     'id': '48VOhlpXMX2a0u2IDMEbtd',
#     'is_local': False,
#     'name': 'Fan Girl',
#     'popularity': 47,
#     'preview_url': 'https://p.scdn.co/mp3-preview/993b1d33bda075f1de4de13b80c9b088a1870b7d?cid=ae0dc287abd746f9bfc9fabb30966d0c',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:48VOhlpXMX2a0u2IDMEbtd'}],
#   'limit': 50,
#   'next': 'https://api.spotify.com/v1/search?query=year%3A2018&type=track&offset=10000&limit=50',
#   'offset': 9950,
#   'previous': 'https://api.spotify.com/v1/search?query=year%3A2018&type=track&offset=9900&limit=50',
#   'total': 100000}}

# %%
# get the artist names with Albums name and run through the Api to get the genre and then merge into the Df.

# %%
print('number of elements in the track_name list:', len(track_name))
# Out:
# number of elements in the track_name list: 10000

# %%
# Get genres of artists
artist_genres = []     
for name in artist_name:
    genres = []
    artists = sp.search(q='artist:' + name, type='artist')
    genres.append(name)
    for i in range(len(artists['artists']['items'])):
        genre = artists['artists']['items'][i]['genres']
        if genre:
            genres.append(genre)

    artist_genres.append(genres)
# Out:
# retrying ...2secs
# retrying ...1secs
# retrying ...2secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...2secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...4secs
# retrying ...1secs
# retrying ...4secs
# retrying ...1secs
# retrying ...4secs
# retrying ...1secs
# retrying ...4secs
# retrying ...1secs
# retrying ...2secs
# retrying ...1secs
# retrying ...3secs
# retrying ...1secs
# retrying ...1secs
# retrying ...3secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...3secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...3secs
# retrying ...1secs
# retrying ...1secs
# retrying ...3secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...4secs
# retrying ...1secs
# retrying ...3secs
# retrying ...1secs

# %%
artist_genres[0:10]
# Out:
# [['Post Malone', ['dfw rap', 'pop', 'rap']],
#  ['A Boogie Wit da Hoodie', ['rap', 'trap music']],
#  ['Meek Mill',
#   ['hip hop', 'philly rap', 'pop', 'pop rap', 'rap', 'trap music']],
#  ['Lil Baby', ['atl hip hop', 'atl trap', 'rap', 'trap music']],
#  ['Travis Scott', ['pop', 'pop rap', 'rap']],
#  ['YNW Melly'],
#  ['Juice WRLD', ['chicago rap', 'trap music']],
#  ['Billie Eilish', ['electropop', 'pop']],
#  ['Marshmello', ['brostep', 'progressive electro house']],
#  ['Post Malone', ['dfw rap', 'pop', 'rap']]]

# %%
# flatten series with list values to multiple rows
#df_expand = pd.DataFrame(df.column.tolist(), index=df.id).stack().reset_index(name=column)[["column","id"]]

# %%
df_test = pd.DataFrame({'artist_name':artist_name,'track_name':track_name,'album_name': album_name,'artist_genres':artist_genres,'track_id':track_id,'popularity':popularity})
print(df_test.shape)
df_test.head()
# Out:
# (10000, 6)
#               artist_name                                     track_name  \
# 0             Post Malone  Sunflower - Spider-Man: Into the Spider-Verse
# 1  A Boogie Wit da Hoodie                        Swervin (feat. 6ix9ine)
# 2               Meek Mill                        Going Bad (feat. Drake)
# 3                Lil Baby               Drip Too Hard (Lil Baby & Gunna)
# 4            Travis Scott                                     SICKO MODE
#
#                                           album_name  \
# 0  Spider-Man: Into the Spider-Verse (Soundtrack ...
# 1                                         Hoodie SZN
# 2                                      Championships
# 3                                        Drip Harder
# 4                                         ASTROWORLD
#
#                                        artist_genres                track_id  \
# 0                 [Post Malone, [dfw rap, pop, rap]]  3KkXRkHbMCARz0aVfEt68P
# 1        [A Boogie Wit da Hoodie, [rap, trap music]]  1wJRveJZLSb1rjhnUHQiv6
# 2  [Meek Mill, [hip hop, philly rap, pop, pop rap...  2IRZnDFmlqMuOrYOLnZZyc
# 3  [Lil Baby, [atl hip hop, atl trap, rap, trap m...  78QR3Wp35dqAhFEc2qAGjE
# 4                [Travis Scott, [pop, pop rap, rap]]  2xLMifQCjDGFmkHkpNLD9h
#
#    popularity
# 0          92
# 1          86
# 2          86
# 3          85
# 4          88

# %%
df_test.shape
# Out:
# (10000, 6)

# %% [markdown]
# ## Spotify Audio Features

# %%
#measuring the time
start = timeit.default_timer()

# empty list, batchsize and the counter for None results
rows = []
batchsize = 100
None_counter = 0

for i in range(0,len(df_test['track_id']),batchsize):
    batch = df_test['track_id'][i:i+batchsize]
    feature_results = sp.audio_features(batch)
    for i, t in enumerate(feature_results):
        if t == None:
            None_counter = None_counter + 1
        else:
            rows.append(t)
            
print('Number of tracks where no audio features were available:',None_counter)

stop = timeit.default_timer()
print ('Time to run this code (in seconds):',stop - start)
# Out:
# Number of tracks where no audio features were available: 0
# Time to run this code (in seconds): 11.035160764000011

# %%
print('number of elements in the track_id list:', len(rows))
# Out:
# number of elements in the track_id list: 10000

# %%
df_audio_features = pd.DataFrame.from_dict(rows,orient='columns')
print("Shape of the dataset:", df_audio_features.shape)
df_audio_features.head()
# Out:
# Shape of the dataset: (10000, 18)
#    acousticness                                       analysis_url  \
# 0       0.55600  https://api.spotify.com/v1/audio-analysis/3KkX...
# 1       0.01530  https://api.spotify.com/v1/audio-analysis/1wJR...
# 2       0.25900  https://api.spotify.com/v1/audio-analysis/2IRZ...
# 3       0.10300  https://api.spotify.com/v1/audio-analysis/78QR...
# 4       0.00513  https://api.spotify.com/v1/audio-analysis/2xLM...
#
#    danceability  duration_ms  energy                      id  \
# 0         0.760       158040   0.479  3KkXRkHbMCARz0aVfEt68P
# 1         0.581       189487   0.662  1wJRveJZLSb1rjhnUHQiv6
# 2         0.889       180522   0.496  2IRZnDFmlqMuOrYOLnZZyc
# 3         0.896       145543   0.671  78QR3Wp35dqAhFEc2qAGjE
# 4         0.834       312820   0.730  2xLMifQCjDGFmkHkpNLD9h
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0               0.0    2    0.0703    -5.574     1       0.0466   89.911
# 1               0.0    9    0.1110    -5.239     1       0.3030   93.023
# 2               0.0    4    0.2520    -6.365     0       0.0905   86.003
# 3               0.0    1    0.5520    -6.977     0       0.2890  112.502
# 4               0.0    8    0.1240    -3.714     1       0.2220  155.008
#
#    time_signature                                         track_href  \
# 0               4  https://api.spotify.com/v1/tracks/3KkXRkHbMCAR...
# 1               4  https://api.spotify.com/v1/tracks/1wJRveJZLSb1...
# 2               4  https://api.spotify.com/v1/tracks/2IRZnDFmlqMu...
# 3               4  https://api.spotify.com/v1/tracks/78QR3Wp35dqA...
# 4               4  https://api.spotify.com/v1/tracks/2xLMifQCjDGF...
#
#              type                                   uri  valence
# 0  audio_features  spotify:track:3KkXRkHbMCARz0aVfEt68P    0.913
# 1  audio_features  spotify:track:1wJRveJZLSb1rjhnUHQiv6    0.434
# 2  audio_features  spotify:track:2IRZnDFmlqMuOrYOLnZZyc    0.544
# 3  audio_features  spotify:track:78QR3Wp35dqAhFEc2qAGjE    0.358
# 4  audio_features  spotify:track:2xLMifQCjDGFmkHkpNLD9h    0.446

# %%
df_audio_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 18 columns):
# acousticness        10000 non-null float64
# analysis_url        10000 non-null object
# danceability        10000 non-null float64
# duration_ms         10000 non-null int64
# energy              10000 non-null float64
# id                  10000 non-null object
# instrumentalness    10000 non-null float64
# key                 10000 non-null int64
# liveness            10000 non-null float64
# loudness            10000 non-null float64
# mode                10000 non-null int64
# speechiness         10000 non-null float64
# tempo               10000 non-null float64
# time_signature      10000 non-null int64
# track_href          10000 non-null object
# type                10000 non-null object
# uri                 10000 non-null object
# valence             10000 non-null float64
# dtypes: float64(9), int64(4), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# <h1>- EDA

# %%
columns_to_drop = ['analysis_url','track_href','type','uri']
df_audio_features.drop(columns_to_drop, axis=1,inplace=True)

df_audio_features.rename(columns={'id': 'track_id'}, inplace=True)

# %%
df_audio_features.shape
# Out:
# (10000, 14)

# %%
df_audio_features.head()
# Out:
#    acousticness  danceability  duration_ms  energy                track_id  \
# 0       0.55600         0.760       158040   0.479  3KkXRkHbMCARz0aVfEt68P
# 1       0.01530         0.581       189487   0.662  1wJRveJZLSb1rjhnUHQiv6
# 2       0.25900         0.889       180522   0.496  2IRZnDFmlqMuOrYOLnZZyc
# 3       0.10300         0.896       145543   0.671  78QR3Wp35dqAhFEc2qAGjE
# 4       0.00513         0.834       312820   0.730  2xLMifQCjDGFmkHkpNLD9h
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0               0.0    2    0.0703    -5.574     1       0.0466   89.911
# 1               0.0    9    0.1110    -5.239     1       0.3030   93.023
# 2               0.0    4    0.2520    -6.365     0       0.0905   86.003
# 3               0.0    1    0.5520    -6.977     0       0.2890  112.502
# 4               0.0    8    0.1240    -3.714     1       0.2220  155.008
#
#    time_signature  valence
# 0               4    0.913
# 1               4    0.434
# 2               4    0.544
# 3               4    0.358
# 4               4    0.446

# %%
df_audio_features.shape
# Out:
# (10000, 14)

# %%
df_audio_features.shape
# Out:
# (10000, 14)

# %% [markdown]
# ### Merging the two Dataframes

# %%
# merge both dataframes
# the 'inner' method will make sure that we only keep track IDs present in both datasets
spotidata = pd.merge(df_test,df_audio_features,on='track_id',how='inner')
print("Shape of the dataset:", df_audio_features.shape)
spotidata.head()
# Out:
# Shape of the dataset: (10000, 14)
#               artist_name                                     track_name  \
# 0             Post Malone  Sunflower - Spider-Man: Into the Spider-Verse
# 1  A Boogie Wit da Hoodie                        Swervin (feat. 6ix9ine)
# 2               Meek Mill                        Going Bad (feat. Drake)
# 3                Lil Baby               Drip Too Hard (Lil Baby & Gunna)
# 4            Travis Scott                                     SICKO MODE
#
#                                           album_name  \
# 0  Spider-Man: Into the Spider-Verse (Soundtrack ...
# 1                                         Hoodie SZN
# 2                                      Championships
# 3                                        Drip Harder
# 4                                         ASTROWORLD
#
#                                        artist_genres                track_id  \
# 0                 [Post Malone, [dfw rap, pop, rap]]  3KkXRkHbMCARz0aVfEt68P
# 1        [A Boogie Wit da Hoodie, [rap, trap music]]  1wJRveJZLSb1rjhnUHQiv6
# 2  [Meek Mill, [hip hop, philly rap, pop, pop rap...  2IRZnDFmlqMuOrYOLnZZyc
# 3  [Lil Baby, [atl hip hop, atl trap, rap, trap m...  78QR3Wp35dqAhFEc2qAGjE
# 4                [Travis Scott, [pop, pop rap, rap]]  2xLMifQCjDGFmkHkpNLD9h
#
#    popularity  acousticness  danceability  duration_ms  energy  \
# 0          92       0.55600         0.760       158040   0.479
# 1          86       0.01530         0.581       189487   0.662
# 2          86       0.25900         0.889       180522   0.496
# 3          85       0.10300         0.896       145543   0.671
# 4          88       0.00513         0.834       312820   0.730
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0               0.0    2    0.0703    -5.574     1       0.0466   89.911
# 1               0.0    9    0.1110    -5.239     1       0.3030   93.023
# 2               0.0    4    0.2520    -6.365     0       0.0905   86.003
# 3               0.0    1    0.5520    -6.977     0       0.2890  112.502
# 4               0.0    8    0.1240    -3.714     1       0.2220  155.008
#
#    time_signature  valence
# 0               4    0.913
# 1               4    0.434
# 2               4    0.544
# 3               4    0.358
# 4               4    0.446

# %% [markdown]
# <h3> check for Missing values

# %%
import missingno as msno
# %matplotlib inline
msno.matrix(spotidata)

# %%
(spotidata.isna().sum()).sum()
# Out:
# 0

# %%
spotidata.shape
# Out:
# (10000, 19)

# %%
spotidata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 0 to 9999
# Data columns (total 19 columns):
# artist_name         10000 non-null object
# track_name          10000 non-null object
# album_name          10000 non-null object
# artist_genres       10000 non-null object
# track_id            10000 non-null object
# popularity          10000 non-null int64
# acousticness        10000 non-null float64
# danceability        10000 non-null float64
# duration_ms         10000 non-null int64
# energy              10000 non-null float64
# instrumentalness    10000 non-null float64
# key                 10000 non-null int64
# liveness            10000 non-null float64
# loudness            10000 non-null float64
# mode                10000 non-null int64
# speechiness         10000 non-null float64
# tempo               10000 non-null float64
# time_signature      10000 non-null int64
# valence             10000 non-null float64
# dtypes: float64(9), int64(5), object(5)
# memory usage: 1.5+ MB

# %%
# group the entries by artist_name and track_name and check for duplicates

grouped = spotidata.groupby(['artist_name','track_name'], as_index=True).size()
grouped[grouped > 1].count()

# %%
#There are 1879 duplicate entries which will be dropped in this cell
spotidata.drop_duplicates(subset=['artist_name','track_name'], inplace=True)

# %%
# verify the dropping
spotidata[spotidata.duplicated(subset=['artist_name','track_name'],keep=False)].count()

# %%
spotidata[spotidata.duplicated(subset=['artist_name','track_name'],keep=False)]

# %%
spotidata.shape

# %%
spotidata.info()

# %%
print(spotipop.shape)
print(spotipop.info())
spotipop.head()

# %%
# with pd.option_context("display.max_rows", 200):
#     display(spotipop)

# %%
spotidata.to_csv('spotidata.csv', index=False)

# %%
spotidata = pd.read_csv('spotidata.csv')

# %%
spotidata.head()

# %%
spotidata["artist_genres"]

# %%
# create new dataframe df_pop ordered consisting of the 20 most popular tracks
df_pop = spotidata.sort_values('popularity', ascending=False)

# %%
df_pop.reset_index(inplace = True)

# %%
df_pop

# %%
bins = [0, 50, 68, 100]
df_pop['binned'] = pd.cut(df_pop['popularity'], bins)

# %%
bins = [0, 50, 68, 100]
labels = [0,1,2]
df_pop['binned'] = pd.cut(df_pop['popularity'], bins=bins, labels=labels)

# %%
df_pop

# %%
# create a new DF with the new binned/classified popularity score 
df_popular = df_pop

# %%
#rename the binned coulmn as Popular

df_popular.rename(columns={'binned':'Popular'},inplace=True)

# %%
#drop the the popularity column and rename the binned one as Popular
df_popular[df_popular.columns.drop('popularity')]
df_popular = df_popular[df_popular.columns.drop('popularity')]

# %%
df_popular

# %%
import ast
# An Abstract Syntax-Tree is a data structure that represents a piece of code in a hierarchical manner, 
# and it greatly facilitates reasoning, analyzing, and even modifying the code in an automated way.

# %%
# Break or flatten the values of the column 
df_pop["artist_genres"] = df_pop["artist_genres"].apply(lambda x: ast.literal_eval(x))

# %%
df_pop.artist_genres[0]

# %%
# flatten series with list values to multiple rows
df_G = pd.DataFrame(df_pop.artist_genres.tolist(), index=df_pop["index"]).stack().reset_index(name="artist_genres")

# %%
df_G.head()

# %%
df_G.artist_genres[0]

# %%
# drop all the artist names by droping values == 0 from the df  
# df_G.loc[df_G.level_1 == 0] 

df_G.drop(df_G.index[df_G['level_1'] == 0], inplace = True)

# %%
df_G.head()

# %%
df_G1 = df_G

# %%
#flatten to the final value for artist_genre
df_G1 = pd.DataFrame(df_G.artist_genres.tolist(), index=df_G["index"]).stack().reset_index(name="artist_genres")

# %%
df_G1

# %%
df_G1[df_G1['artist_genres'].str.match('pop')]

# %%
sp.recommendation_genre_seeds()

# %%
df_G2 = df_G1.apply(lambda x: 'pop' if 'pop' in x else x)

# %%
print(type(df_G2))

# %%
df_G2

# %%
#replace all the genre that includes "pop" genres to "pop"
df_G2['artist_genres'] = df_G2.artist_genres.str.replace(r'(^.*pop.*$)', 'pop')
df_G2

# %%
df_G2.head()

# %%
# get the the word that occur the most and get the top 10 genre from that.
df_G2['artist_genres'].describe()

# %%
# merge both dataframes
# the 'inner' method will make sure that we only keep track IDs present in both datasets
df_genre = pd.merge(df_G2,df_popular,on='index',how='inner')

# %%
df_genre.rename(columns={'artist_genres_x':'artist_genres','artist_genres_y':'All_genres'},inplace=True)

# %%
df_genre = df_genre[df_genre.columns.drop('level_1','instrumentalness')]

# %%
# df_genre = df_genre[["index",'artist_name','artist_genres',
#                      'album_name','track_name',
#                      "All_genres","track_id",'Popular','acousticness','danceability',
#                      'duration_ms','energy','key','liveness','loudness',
#                      'speechiness','tempo','time_signature','valence']]

# %%
df_genre['artist_genres'].unique().shape

# %%
df_genre.to_csv('df_genre.csv', index=False)

# %%
df_genre['artist_genres'] = df_genre.artist_genres.str.replace(r'(^.*blues.*$)', 'blues')

# %%
df_genre['artist_genres'].value_counts()

# %%
df_genre.shape

# %%
Top_Genre = df_genre[df_genre['artist_genres'].isin(['pop', 'rap',"hip hop","rock","house","r&b","indie",
                                                     "country","latin","metal","folk","blues"])]

# %%
df_genre.head()

# %%
Top_Genre = pd.read_csv("Top_Genre.csv")

# %%
Top_Genre.head()

# %%
grouped = Top_Genre.groupby(['artist_name','track_name'], as_index=True).size()
grouped[grouped > 1].count()

# %%
#There are 5413 duplicate entries which will be dropped in this cell
Top_Genre.drop_duplicates(subset=['artist_name','track_name'], inplace=True)

# %%
# check for any duplicates and drop them
Top_Genre[Top_Genre.duplicated(subset=['artist_name','track_name'],keep=False)].count()

# %%
Top_Genre["track_name"].unique

# %%
Top_Genre.head()

# %%
Top_Genre= Top_Genre.reset_index(drop=True)

# %%
Top_Genre.to_csv('Top_Genre.csv', index=False)

# %%
Top_Genre.head()
Top_Genre.shape

# %%
Top_Genre["artist_genres"].value_counts()

# %%
# Create a set of dummy variables from the artist_genres variable


genre_matrix = pd.get_dummies(Top_Genre["artist_genres"])

# %%
genre_matrix.head()

# %%
# Join the dummy variables to the main dataframe
spotifinal = pd.concat([Top_Genre, genre_matrix], axis=1)
spotifinal.head()

# %%
spotifinal.columns

# %%
spotifinal[spotifinal['rock']>0.5]

# %%
spotifinal

# %%
spotifinal.to_csv('spotifinal.csv', index=False)

# %%
spotifinal = pd.read_csv('spotifinal.csv')

# %%
spotifinal.shape

# %%
# Exploring Class Imbalance
print('Target Variable')
print(df_genre.groupby(["Popular"]).Popular.count())
print("\n")
print("0 = Unpopular")
print("1 = Popular")
print("2 = Very Popular")

# Target Variable Countplot
plt.figure(figsize = (10, 5))
sns.countplot(df_genre["Popular"], alpha = .70, palette = "BuPu")
plt.title("Popularity")
plt.ylabel("Songs")
plt.show()

# %%
for col, col_data in x.iteritems():
    if str(col)=='item':
        col_data = pd.get_dummies(col_data, prefix = col)
        x = x.join(col_data)

# %%
for genre, genre_data in df_genre.genre_data():
    if str(col)=='artist_genres':
        genre_data = df_genre.get_dummies(genre_data, prefix = col)
        df_genre = df_genre.join(genre_data)
print(df_genre)

# %%
genre_count = spotifinal["artist_genres"].value_counts()
sns.set(style="darkgrid")
sns.barplot(genre_count.index, genre_count.values, alpha=0.8)
plt.title('Frequency Distribution of genres')
plt.ylabel('Number of Occurrences', fontsize=12)
plt.xlabel('Genre', fontsize=12)
plt.figure(figsize=(15,20))
plt.show()

# %%
# labels = cat_df_flights['carrier'].astype('category').cat.categories.tolist()
# counts = cat_df_flights['carrier'].value_counts()
# sizes = [counts[var_cat] for var_cat in labels]
# fig1, ax1 = plt.subplots()
# ax1.pie(sizes, labels=labels, autopct='%1.1f%%', shadow=True) #autopct is show the % on plot
# ax1.axis('equal')
# plt.show()

# %%
from surprise.model_selection import cross_validate
from surprise.prediction_algorithms import SVD
from surprise.prediction_algorithms import KNNWithMeans, KNNBasic, KNNBaseline
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer
from surprise.model_selection import GridSearchCV
from sklearn.preprocessing import PolynomialFeatures

# %%
# instantiating and generating the count matrix
count = CountVectorizer()
count_matrix = count.fit_transform(spotifinal['artist_genres'])

# creating a Series for the song titles so they are associated to an ordered numerical
# list I will use later to match the indexes
indices = pd.Series(spotifinal.track_name)
indices[:5]

# %%
# generating the cosine similarity matrix
cosine_sim = cosine_similarity(count_matrix, count_matrix)
cosine_sim

# %%
# function that takes in song title as input and returns the top 10 recommended songs
def recommendations(title, cosine_sim = cosine_sim):
    
    recommended_songs = []
    
    # gettin the index of the song that matches the title
    idx = indices[indices == title].index[0]

    # creating a Series with the similarity scores in descending order
    score_series = pd.Series(cosine_sim[idx]).sort_values(ascending = False)

    # getting the indexes of the 10 most similar songs
    top_10_indexes = list(score_series.iloc[1:11].index)
    
    # populating the list with the titles of the best 10 matching songs
    for i in top_10_indexes:
        recommended_songs.append(list(spotifinal.track_name)[i])
        
    return recommended_songs

# %%
recommendations('Amanece')

# %%
spotifinal.loc[spotifinal['track_name'] == 'Mi Gente']

# %%
spotifinal.columns

# %%
# instantiating and generating the count matrix with multiple variables 
count = CountVectorizer()
count_matrix = count.fit_transform(spotifinal['artist_genres']) # [['artist_genres','Popular','danceability','energy']])

# creating a Series for the song titles so they are associated to an ordered numerical
# list I will use later to match the indexes
indices = pd.Series(spotifinal.artist_name + ' - ' + spotifinal.track_name + ' - ' + spotifinal.artist_genres)
indices[:5]

# %%
cosine_sim = cosine_similarity(count_matrixX, count_matrixX)
cosine_sim

# %%
#print(count_matrix)
#access the count_matrix
#append the pop score for each song
count_matrix[0].A
#print(count_matrix)
type(count_matrix)

# %%
count_matrix.shape

# %%
# sample = numpy.append(count_matrix[0].A ,spotifinal['Popular'][0])
# sample

# %%
# count_matrixX[0].A = numpy.append(count_matrixX[0].A , 2)
count_matrix.A
count_multiple_matrix = np.c_[count_matrix.A , spotifinal[['Popular','danceability','energy']]]

# %%
count_multiple_matrix

# %%
count_multiple_matrix.shape

# %%
# generating the cosine similarity matrix
cosine_sim = cosine_similarity(count_multiple_matrix, count_multiple_matrix)
cosine_sim

# %%
# function that takes in song title as input and returns the top 10 recommended songs
def recommendations(title, cosine_sim = cosine_sim):
    
    recommended_songs = []
    
    # gettin the index of the song that matches the title
    idx = indices[indices == title].index[0]

    # creating a Series with the similarity scores in descending order
    score_series = pd.Series(cosine_sim[idx]).sort_values(ascending = False)

    # getting the indexes of the 10 most similar songs
    top_10_indexes = list(score_series.iloc[1:11].index)
    
    # populating the list with the titles of the best 10 matching songs
    for i in top_10_indexes:
        recommended_songs.append(list(spotifinal.artist_name + ' - ' + spotifinal.track_name + ' - ' + spotifinal.artist_genres)[i])
        
    return recommended_songs

# %%
recommendations('Amanece')

# %% [markdown]
# <h1>- Specifying item-based KNNBasic model

# %%
from surprise import Dataset, SVD, KNNBaseline, KNNBasic, KNNWithMeans, KNNWithZScore, Reader, NMF, SlopeOne, NormalPredictor, BaselineOnly, CoClustering
from surprise.model_selection import cross_validate
from surprise.similarities import cosine
from collections import defaultdict

import os
from surprise import SVDpp
from surprise import accuracy
from surprise.model_selection import train_test_split
from surprise import BaselineOnly
from surprise import Reader
from surprise.model_selection import KFold
from surprise.model_selection import GridSearchCV
from surprise import Trainset

# %%
benchmark = []
# Iterate over all algorithms
for algorithm in [SVD(), SVDpp(), KNNBaseline(), KNNBasic(), KNNWithMeans(), KNNWithZScore(), NMF(), SlopeOne(), NormalPredictor(), BaselineOnly(), CoClustering()]:
    
# Perform cross validation
    results = cross_validate(algorithm, spotifinal, measures=['RMSE'], cv=3, verbose=False)
    
# Get results & append algorithm name
    tmp = pd.spotifinal.from_dict(results).mean(axis=0)
    tmp = tmp.append(pd.Series([str(algorithm).split(' ')[0].split('.')[-1]], index=['Algorithm']))
    benchmark.append(tmp)
    
pd.spotifinal(benchmark).set_index('Algorithm').sort_values('test_rmse')

# %%
#compare item-item

sim_options = {'name': 'cosine',
               'user_based': False  # compute  similarities between *items*
               }
algo = KNNBaseline(cosine_sim=cosine_sim)

# %%
# # Tracks Popularity with ratings above and equal to 84-94 as Very Popular
# df_pop[df_pop.popularity == 2]
# df_pop.loc[df_pop.popularity>=84, "popularity"] = 2

# %%
# # Tracks Popularity with ratings between(70-84) as popular
# df_pop.loc[(df_pop.popularity < 84) & (df_pop.popularity != 2), "popularity"] = 1

# %%
# # Tracks Popularity with score below 70 as unpopular
# df_pop.loc[(df_pop.popularity < 70) & (df_pop.popularity != 1 & df_pop.popularity != 2), "popularity"] = 0

# %%
# we can create overlaid or side-by-side bargraph. You need to shift the x value by width to accommodate for two graphs.
from matplotlib import pyplot as plt
fig = plt.figure()
n = 1 # This is our first dataset (out of 2) 
t = 2 # Number of datasets 
d = 6 # Number of sets of bars 
w = 0.8 # Width of each bar 
dog_values = [t*element + w*n for element in range(d)] # essentially, this list comprehension gives us the position
# of the position of dogs
plt.bar(dog_values,dogs_age, color='green')
n = 2  # This is our second dataset (out of 2)
t = 2 # Number of datasets
d = 6 # Number of sets of bars
w = 0.8 # Width of each bar
cat_values = [t*element + w*n for element in range(d)]
plt.bar(cat_values, cats_age, color = 'purple')
plt.legend(["track_name", "cats"])
n = 1

# %%
client_id = 'ae0dc287abd746f9bfc9fabb30966d0c'
client_secret = '40c2e16da28c49e1839219c99e697910'
redirect_uri= "http://meldebek.com/callback/" 
scope = "playlist-read-private user-library-read"
if len(sys.argv) > 1:
    username = sys.argv[1]
else:
    print(": %s username" % (sys.argv[0],))
    sys.exit()

token = util.prompt_for_user_token(username,scope,client_id,client_secret,redirect_uri)

# %%
cid ="ae0dc287abd746f9bfc9fabb30966d0c" 
secret = "40c2e16da28c49e1839219c99e697910"
username= "Mohamad Eldebek"

client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

artist_name = []
track_name = []
track_id = [] 
popularity = []
album_name = []


for i in range(0,10000,50):
    genre_pop_results = sp.search(q='genre:pop', type='track', limit=50,offset=i)
    for i, t in enumerate(genre_pop_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        album_name.append(t['album']['name'])

# %%
genre_pop_results

# %%
track_name

# %%
df_genre_jazz = pd.DataFrame({'artist_name':artist_name,'track_name':track_name,'album_name': album_name,'track_id':track_id,'popularity':popularity})
print(df_genre_jazz.shape)
df_genre_jazz

# %%
df_genre_pop

# %% [markdown]
# <h1> Input Songs for recommendation¶

# %%
from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
from IPython.display import display

# %%
# function that takes in song title as input and returns the top 10 recommended songs
def recommendations(title, cosine_sim = cosine_sim):
    
    recommended_songs = []
    
    # gettin the index of the song that matches the title
    idx = indices[indices == title].index[0]

    # creating a Series with the similarity scores in descending order
    score_series = pd.Series(cosine_sim[idx]).sort_values(ascending = False)

    # getting the indexes of the 10 most similar songs
    top_10_indexes = list(score_series.iloc[1:11].index)
    
    # populating the list with the titles of the best 10 matching songs
    for i in top_10_indexes:
        recommended_songs.append(list(spotifinal.track_name)[i])
        
    return recommended_songs

# %%
x = input()

# %%
recommendations(x)

# %%
recommendations('Amanece')

# %%
S = widgets.Textarea(
    value='Hello World',
    placeholder='Type something',
    description='String:',
    disabled=False
)

# %%
S

# %%
S.value

# %%
interact(recommendations, title="Amanece")

# %%
s = interact(f, x='Hi there!');

# %%
title = spotifinal["track_name"]
idx = x
S = interact(recommendations, recommended_songs = idx)

# %%
interact(recommendations, recommended_songs='Hi there!');

# %%
# The popularity of a track is a value between 0 and 100, with 100 being the most popular. 
# The popularity is calculated by algorithm and is based, in the most part, on the total number of plays 
# the track has had and how recent those plays are.
# Generally speaking, songs that are being played a lot now will have a higher popularity than songs that were 
# played a lot in the past. Duplicate tracks (e.g. the same track from a single and an album) are rated independently. 
# Artist and album popularity is derived mathematically from track popularity. Note that the popularity value may 
# lag actual popularity by a few days: the value is not updated in real time.
