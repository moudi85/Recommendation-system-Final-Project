# %%
import json
import requests
from furl import furl
from math import ceil

# to save some typing
import pandas as pd
import matplotlib

# to display plots in the notebook
# %matplotlib inline
import matplotlib.pyplot as plt
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from __future__ import print_function    # (at top of module)
import time
import pandas as pd
import numpy as np
import re
import spotipy
import sys
import os
import json
import pprint
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy.oauth2 as oauth2
import spotipy.util as util
# Out:
#   File "<ipython-input-1-11c2f76c0f49>", line 18
#     import numpy as np
#            ^
# SyntaxError: from __future__ imports must occur at the beginning of the file

# %%
import os
import spotipy
## Importing the spotipy Library ##
##os.chdir("C:/Punisher/1 UTD/Spring 18/spotify shizzle")

### IMPORTS ##
import pandas as pd
import numpy as np

from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
# to display plots in the notebook
# %matplotlib inline
import matplotlib.pyplot as plt

## importing packages for visualization ##

import seaborn as sns
import spotipy.util as util

# initialize spotify api

spotify = spotipy.Spotify()
from spotipy.oauth2 import SpotifyClientCredentials

# %%
from __future__ import print_function    # (at top of module)
import time
import pandas as pd
import numpy as np
import re
import spotipy
import sys
import os
import json
import pprint
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy.oauth2 as oauth2
import spotipy.util as util

cid ="ae0dc287abd746f9bfc9fabb30966d0c" 
secret = "40c2e16da28c49e1839219c99e697910"
username= "Mohamad Eldebek"

client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

artist_name = []
track_name = []
track_id = [] 
popularity = []



for i in range(0,10000,50):
    track_results = sp.search(q='year:2018', type='track', limit=50,offset=i)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
# for i in range(0,10000,50):
#     results = sp.search(q='Moby', limit=20)
# for i, t in enumerate(results['tracks']['items']):
#     print(' ', i, t['name'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-7060497920d4> in <module>
#      28
#      29 for i in range(0,10000,50):
# ---> 30     track_results = sp.search(q='year:2018', type='track', limit=50,offset=i)
#      31     for i, t in enumerate(track_results['tracks']['items']):
#      32         artist_name.append(t['artists'][0]['name'])
#
# /anaconda3/lib/python3.7/site-packages/spotipy/client.py in search(self, q, limit, offset, type, market)
#     337                 - market - An ISO 3166-1 alpha-2 country code or the string from_token.
#     338         '''
# --> 339         return self._get('search', q=q, limit=limit, offset=offset, type=type, market=market)
#     340
#     341     def user(self, user):
#
# /anaconda3/lib/python3.7/site-packages/spotipy/client.py in _get(self, url, args, payload, **kwargs)
#     144         while retries > 0:
#     145             try:
# --> 146                 return self._internal_call('GET', url, payload, kwargs)
#     147             except SpotifyException as e:
#     148                 retries -= 1
#
# /anaconda3/lib/python3.7/site-packages/spotipy/client.py in _internal_call(self, method, url, payload, params)
#     106         if self.trace_out:
#     107             print(url)
# --> 108         r = self._session.request(method, url, headers=headers, proxies=self.proxies, **args)
#     109
#     110         if self.trace:  # pragma: no cover
#
# /anaconda3/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# /anaconda3/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# /anaconda3/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# /anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# /anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# /anaconda3/lib/python3.7/http/client.py in getresponse(self)
#    1319         try:
#    1320             try:
# -> 1321                 response.begin()
#    1322             except ConnectionError:
#    1323                 self.close()
#
# /anaconda3/lib/python3.7/http/client.py in begin(self)
#     294         # read until we get a non-100 response
#     295         while True:
# --> 296             version, status, reason = self._read_status()
#     297             if status != CONTINUE:
#     298                 break
#
# /anaconda3/lib/python3.7/http/client.py in _read_status(self)
#     255
#     256     def _read_status(self):
# --> 257         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     258         if len(line) > _MAXLINE:
#     259             raise LineTooLong("status line")
#
# /anaconda3/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# /anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     292     def recv_into(self, *args, **kwargs):
#     293         try:
# --> 294             return self.connection.recv_into(*args, **kwargs)
#     295         except OpenSSL.SSL.SysCallError as e:
#     296             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# /anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1819             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1820         else:
# -> 1821             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1822         self._raise_ssl_error(self._ssl, result)
#    1823
#
# KeyboardInterrupt:

# %%
track_results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=roadhouse%2520blues&type=track&offset=9950&limit=20',
#   'items': [],
#   'limit': 20,
#   'next': None,
#   'offset': 9950,
#   'previous': 'https://api.spotify.com/v1/search?query=roadhouse%2520blues&type=track&offset=9930&limit=20',
#   'total': 0}}

# %%
from __future__ import print_function    # (at top of module)
import time
import pandas as pd
import numpy as np
import re
import spotipy
import sys
import os
import json
import pprint
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy.oauth2 as oauth2
import spotipy.util as util

cid ="ae0dc287abd746f9bfc9fabb30966d0c" 
secret = "40c2e16da28c49e1839219c99e697910"
username= "Mohamad Eldebek"

client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

#user_id = []
track_name = []
track_id = []
artist_name = []
playlist_id = []
popularity = []
#playlist_id = []

# import timeit
# start = timeit.default_timer()

# for i in range(0,10000,50):
#     track_results = sp.search(q='year:2019', type='track', limit=50,offset=i)
#     for i, t in enumerate(track_results['tracks']['items']):
#         artist_name.append(t['artists'][0]['name'])
#         track_name.append(t['name'])
#         track_id.append(t['id'])
#         popularity.append(t['popularity'])
results = sp.search(q='kanye', limit=20)
        for i, t in enumerate(results['tracks']['items']):
            stop = timeit.default_timer()
print ('Time to run this code (in seconds):', stop - start)
print(' ', i, t['name'])

# %%
print('number of elements in the track_results list:', len(track_id))
# Out:
# number of elements in the track_results list: 0

# %%
cid ="ae0dc287abd746f9bfc9fabb30966d0c" 
secret = "40c2e16da28c49e1839219c99e697910"
username= "Mohamad Eldebek"

client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

artist_name = []
track_name = []
track_id = [] 
popularity = []



for i in range(0,10000,50):
    track_results = sp.search(q='year:2018', type='track', limit=50,offset=i)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        
        results = sp.search(q='kanye', limit=20)
for i, t in enumerate(results['tracks']['items']):
    print(' ', i, t['name'])

# %%
print('number of elements in the track_id list:', len(track_id))
# Out:
# number of elements in the track_id list: 10000

# %%
df_tracks = pd.DataFrame({'artist_name':artist_name,'track_name':track_name,'track_id':track_id,'popularity':popularity})
print(df_tracks.shape)
df_tracks.head()
# Out:
# (10000, 4)
#    artist_name                                     track_name  \
# 0  Post Malone  Sunflower - Spider-Man: Into the Spider-Verse
# 1    Meek Mill                        Going Bad (feat. Drake)
# 2    YNW Melly                              Murder On My Mind
# 3     Lil Baby               Drip Too Hard (Lil Baby & Gunna)
# 4       Calboy                                        Envy Me
#
#                  track_id  popularity
# 0  3KkXRkHbMCARz0aVfEt68P          95
# 1  2IRZnDFmlqMuOrYOLnZZyc          89
# 2  7eBqSVxrzQZtK2mmgRG6lC          88
# 3  78QR3Wp35dqAhFEc2qAGjE          86
# 4  05t7JMip6JrLuSrMV5yYjX          86

# %%
track_results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=year%3A2018&type=track&offset=9950&limit=50',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5TM9R6dNoJSMq23yZQD6Ee'},
#        'href': 'https://api.spotify.com/v1/artists/5TM9R6dNoJSMq23yZQD6Ee',
#        'id': '5TM9R6dNoJSMq23yZQD6Ee',
#        'name': 'Don Q',
#        'type': 'artist',
#        'uri': 'spotify:artist:5TM9R6dNoJSMq23yZQD6Ee'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1mWXVCy3lYeeMADCjUgVto'},
#      'href': 'https://api.spotify.com/v1/albums/1mWXVCy3lYeeMADCjUgVto',
#      'id': '1mWXVCy3lYeeMADCjUgVto',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/68ae54ecfc2934ee2b2f12f350cfd40a10b76d93',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/303b13b077fdd0e27f038b1561e242e8dde6ebb1',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/fc408549948bbcc5671f3ac440f3dfba13e69e23',
#        'width': 64}],
#      'name': 'Don Season 2',
#      'release_date': '2018-08-31',
#      'release_date_precision': 'day',
#      'total_tracks': 18,
#      'type': 'album',
#      'uri': 'spotify:album:1mWXVCy3lYeeMADCjUgVto'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5TM9R6dNoJSMq23yZQD6Ee'},
#       'href': 'https://api.spotify.com/v1/artists/5TM9R6dNoJSMq23yZQD6Ee',
#       'id': '5TM9R6dNoJSMq23yZQD6Ee',
#       'name': 'Don Q',
#       'type': 'artist',
#       'uri': 'spotify:artist:5TM9R6dNoJSMq23yZQD6Ee'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 177995,
#     'explicit': True,
#     'external_ids': {'isrc': 'USAT21810931'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6JJl2d9XS9UKA31rXFVhDK'},
#     'href': 'https://api.spotify.com/v1/tracks/6JJl2d9XS9UKA31rXFVhDK',
#     'id': '6JJl2d9XS9UKA31rXFVhDK',
#     'is_local': False,
#     'name': 'Weakness',
#     'popularity': 42,
#     'preview_url': 'https://p.scdn.co/mp3-preview/64575dcff63e5cc2806efa09bf67ed6a88a8c54d?cid=ae0dc287abd746f9bfc9fabb30966d0c',
#     'track_number': 11,
#     'type': 'track',
#     'uri': 'spotify:track:6JJl2d9XS9UKA31rXFVhDK'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7ItbAZITSFxSy5LJChXe18'},
#        'href': 'https://api.spotify.com/v1/artists/7ItbAZITSFxSy5LJChXe18',
#        'id': '7ItbAZITSFxSy5LJChXe18',
#        'name': 'ford.',
#        'type': 'artist',
#        'uri': 'spotify:artist:7ItbAZITSFxSy5LJChXe18'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0gYEZtX2UnrVx0qoMcMc2Q'},
#      'href': 'https://api.spotify.com/v1/albums/0gYEZtX2UnrVx0qoMcMc2Q',
#      'id': '0gYEZtX2UnrVx0qoMcMc2Q',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/b4d713989216ba49f144452d1ec4a5d0fb81a61a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/1196d79ce5a1ab950c4265cc4e6283013a3d674e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/7ee06cc9d7e5a980a63227e3df3bd9580c5e18ee',
#        'width': 64}],
#      'name': 'Sirens',
#      'release_date': '2018-04-18',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:0gYEZtX2UnrVx0qoMcMc2Q'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7ItbAZITSFxSy5LJChXe18'},
#       'href': 'https://api.spotify.com/v1/artists/7ItbAZITSFxSy5LJChXe18',
#       'id': '7ItbAZITSFxSy5LJChXe18',
#       'name': 'ford.',
#       'type': 'artist',
#       'uri': 'spotify:artist:7ItbAZITSFxSy5LJChXe18'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 216000,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZCE61823889'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6qgYf5sgAJfizYlhNDHoph'},
#     'href': 'https://api.spotify.com/v1/tracks/6qgYf5sgAJfizYlhNDHoph',
#     'id': '6qgYf5sgAJfizYlhNDHoph',
#     'is_local': False,
#     'name': 'Sirens',
#     'popularity': 45,
#     'preview_url': 'https://p.scdn.co/mp3-preview/032a0b42106b2e0c1ebaa55ca38bca1b4465f515?cid=ae0dc287abd746f9bfc9fabb30966d0c',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6qgYf5sgAJfizYlhNDHoph'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6A4zNM8ZYOZkgzYmq60tJT'},
#        'href': 'https://api.spotify.com/v1/artists/6A4zNM8ZYOZkgzYmq60tJT',
#        'id': '6A4zNM8ZYOZkgzYmq60tJT',
#        'name': 'Void',
#        'type': 'artist',
#        'uri': 'spotify:artist:6A4zNM8ZYOZkgzYmq60tJT'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3Ft9Jav3hm2mGNVEO08DQY'},
#      'href': 'https://api.spotify.com/v1/albums/3Ft9Jav3hm2mGNVEO08DQY',
#      'id': '3Ft9Jav3hm2mGNVEO08DQY',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/39e05eb916538ca4fee7bf4368401600a48fc851',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/c5e7bbfc4d1f0be4138bac3ea15a26817b4d165b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/d2bdb78c400692e1d1a0c09373789575246c4d39',
#        'width': 64}],
#      'name': 'Stop',
#      'release_date': '2018-03-15',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:3Ft9Jav3hm2mGNVEO08DQY'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6A4zNM8ZYOZkgzYmq60tJT'},
#       'href': 'https://api.spotify.com/v1/artists/6A4zNM8ZYOZkgzYmq60tJT',
#       'id': '6A4zNM8ZYOZkgzYmq60tJT',
#       'name': 'Void',
#       'type': 'artist',
#       'uri': 'spotify:artist:6A4zNM8ZYOZkgzYmq60tJT'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 174420,
#     'explicit': True,
#     'external_ids': {'isrc': 'TCADX1859323'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7LtStR1NZNoQdHOKz6mO1H'},
#     'href': 'https://api.spotify.com/v1/tracks/7LtStR1NZNoQdHOKz6mO1H',
#     'id': '7LtStR1NZNoQdHOKz6mO1H',
#     'is_local': False,
#     'name': 'Stop',
#     'popularity': 40,
#     'preview_url': 'https://p.scdn.co/mp3-preview/20b519aad3922e327ed7178af2a6223a6d20c40d?cid=ae0dc287abd746f9bfc9fabb30966d0c',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:7LtStR1NZNoQdHOKz6mO1H'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Ad91Jof8Niiw0lGLLi3NW'},
#        'href': 'https://api.spotify.com/v1/artists/6Ad91Jof8Niiw0lGLLi3NW',
#        'id': '6Ad91Jof8Niiw0lGLLi3NW',
#        'name': 'YUNGBLUD',
#        'type': 'artist',
#        'uri': 'spotify:artist:6Ad91Jof8Niiw0lGLLi3NW'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5hI3spgjZAqc9ZTPRCMedd'},
#      'href': 'https://api.spotify.com/v1/albums/5hI3spgjZAqc9ZTPRCMedd',
#      'id': '5hI3spgjZAqc9ZTPRCMedd',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/4b84051e6d1d39b36cb2f9f69d9f473f5456d792',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/d27c94ea2e2578e0669dc4d0e54f962c19b5ad1a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/d2b7b58e76560a8594b1a7c042f1bf780a94edfc',
#        'width': 64}],
#      'name': 'YUNGBLUD (Unplugged)',
#      'release_date': '2018-08-10',
#      'release_date_precision': 'day',
#      'total_tracks': 7,
#      'type': 'album',
#      'uri': 'spotify:album:5hI3spgjZAqc9ZTPRCMedd'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Ad91Jof8Niiw0lGLLi3NW'},
#       'href': 'https://api.spotify.com/v1/artists/6Ad91Jof8Niiw0lGLLi3NW',
#       'id': '6Ad91Jof8Niiw0lGLLi3NW',
#       'name': 'YUNGBLUD',
#       'type': 'artist',
#       'uri': 'spotify:artist:6Ad91Jof8Niiw0lGLLi3NW'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 204967,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUG11800781'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0B7ySXTo4LHJwVpmFyPx10'},
#     'href': 'https://api.spotify.com/v1/tracks/0B7ySXTo4LHJwVpmFyPx10',
#     'id': '0B7ySXTo4LHJwVpmFyPx10',
#     'is_local': False,
#     'name': 'California - Unplugged',
#     'popularity': 47,
#     'preview_url': None,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:0B7ySXTo4LHJwVpmFyPx10'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2CDoBLpNRmnspcfY6Rci1U'},
#      'href': 'https://api.spotify.com/v1/albums/2CDoBLpNRmnspcfY6Rci1U',
#      'id': '2CDoBLpNRmnspcfY6Rci1U',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/2fb60b27dc8e3f428118ff1198e5ff352177d94d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/d48a2b3f7b0a82f3a710eb238178cde5e8d0455d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/8b64e3270f60eff061d1b716cd795214d67f8927',
#        'width': 64}],
#      'name': 'Gazab Ka Hai Din (From "Dil Juunglee")',
#      'release_date': '2018-01-27',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:2CDoBLpNRmnspcfY6Rci1U'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1tqysapcCh1lWEAc9dIFpa'},
#       'href': 'https://api.spotify.com/v1/artists/1tqysapcCh1lWEAc9dIFpa',
#       'id': '1tqysapcCh1lWEAc9dIFpa',
#       'name': 'Jubin Nautiyal',
#       'type': 'artist',
#       'uri': 'spotify:artist:1tqysapcCh1lWEAc9dIFpa'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/59pq5Vw16UDkR9txoPKv86'},
#       'href': 'https://api.spotify.com/v1/artists/59pq5Vw16UDkR9txoPKv86',
#       'id': '59pq5Vw16UDkR9txoPKv86',
#       'name': 'Prakriti Kakar',
#       'type': 'artist',
#       'uri': 'spotify:artist:59pq5Vw16UDkR9txoPKv86'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4f7KfxeHq9BiylGmyXepGt'},
#       'href': 'https://api.spotify.com/v1/artists/4f7KfxeHq9BiylGmyXepGt',
#       'id': '4f7KfxeHq9BiylGmyXepGt',
#       'name': 'Tanishk Bagchi',
#       'type': 'artist',
#       'uri': 'spotify:artist:4f7KfxeHq9BiylGmyXepGt'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2owjgBZQ70LoCNHIgW3gSk'},
#       'href': 'https://api.spotify.com/v1/artists/2owjgBZQ70LoCNHIgW3gSk',
#       'id': '2owjgBZQ70LoCNHIgW3gSk',
#       'name': 'Anand-Milind',
#       'type': 'artist',
#       'uri': 'spotify:artist:2owjgBZQ70LoCNHIgW3gSk'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 236325,
#     'explicit': False,
#     'external_ids': {'isrc': 'INS181800175'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0lpDlWrV0Cw3eGGvPU6d3R'},
#     'href': 'https://api.spotify.com/v1/tracks/0lpDlWrV0Cw3eGGvPU6d3R',
#     'id': '0lpDlWrV0Cw3eGGvPU6d3R',
#     'is_local': False,
#     'name': 'Gazab Ka Hai Din (From "Dil Juunglee")',
#     'popularity': 54,
#     'preview_url': 'https://p.scdn.co/mp3-preview/5a55cc7892c565c598a7313983e29b363808fc47?cid=ae0dc287abd746f9bfc9fabb30966d0c',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0lpDlWrV0Cw3eGGvPU6d3R'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3KOHpygRuo1ruQAbEneR3t'},
#        'href': 'https://api.spotify.com/v1/artists/3KOHpygRuo1ruQAbEneR3t',
#        'id': '3KOHpygRuo1ruQAbEneR3t',
#        'name': 'George FitzGerald',
#        'type': 'artist',
#        'uri': 'spotify:artist:3KOHpygRuo1ruQAbEneR3t'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/52LJO0cNeBErBohaxNZ0t4'},
#      'href': 'https://api.spotify.com/v1/albums/52LJO0cNeBErBohaxNZ0t4',
#      'id': '52LJO0cNeBErBohaxNZ0t4',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/17fad53d4f3ce7864fa01097d37a38f7ff033627',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/468df0fa541ffc973589e18ec4784a8345437313',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/98ba113250e6277f9641cddcfe4c38eb61c95498',
#        'width': 64}],
#      'name': 'All That Must Be',
#      'release_date': '2018-03-09',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:52LJO0cNeBErBohaxNZ0t4'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3KOHpygRuo1ruQAbEneR3t'},
#       'href': 'https://api.spotify.com/v1/artists/3KOHpygRuo1ruQAbEneR3t',
#       'id': '3KOHpygRuo1ruQAbEneR3t',
#       'name': 'George FitzGerald',
#       'type': 'artist',
#       'uri': 'spotify:artist:3KOHpygRuo1ruQAbEneR3t'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2Kv0ApBohrL213X9avMrEn'},
#       'href': 'https://api.spotify.com/v1/artists/2Kv0ApBohrL213X9avMrEn',
#       'id': '2Kv0ApBohrL213X9avMrEn',
#       'name': 'Lil Silva',
#       'type': 'artist',
#       'uri': 'spotify:artist:2Kv0ApBohrL213X9avMrEn'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 208930,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBCEL1700521'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0smkE9zt2Bg7fFk0HlzR4C'},
#     'href': 'https://api.spotify.com/v1/tracks/0smkE9zt2Bg7fFk0HlzR4C',
#     'id': '0smkE9zt2Bg7fFk0HlzR4C',
#     'is_local': False,
#     'name': 'Roll Back',
#     'popularity': 48,
#     'preview_url': 'https://p.scdn.co/mp3-preview/f633339645a2d569bf591f4b1a7ce5c0acc0a93f?cid=ae0dc287abd746f9bfc9fabb30966d0c',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:0smkE9zt2Bg7fFk0HlzR4C'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2Zr4dXYKU1x1MWMikXpWR9'},
#      'href': 'https://api.spotify.com/v1/albums/2Zr4dXYKU1x1MWMikXpWR9',
#      'id': '2Zr4dXYKU1x1MWMikXpWR9',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/1cfbddf5a34c373e1d555f8f2a442be51a3804de',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/008b492e1169c5b59e1b978ecf4504c86cb67b4d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/bbcc7534b1cfd22e50b6b0d400e11f5c153d6d4b',
#        'width': 64}],
#      'name': 'B: The Beginning THE IMAGE ALBUM',
#      'release_date': '2018-03-07',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:2Zr4dXYKU1x1MWMikXpWR9'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5czW6bitDSKbNBNDizRT9p'},
#       'href': 'https://api.spotify.com/v1/artists/5czW6bitDSKbNBNDizRT9p',
#       'id': '5czW6bitDSKbNBNDizRT9p',
#       'name': 'Marty Friedman',
#       'type': 'artist',
#       'uri': 'spotify:artist:5czW6bitDSKbNBNDizRT9p'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1Bk56nx76xE4nP01ZhDsPE'},
#       'href': 'https://api.spotify.com/v1/artists/1Bk56nx76xE4nP01ZhDsPE',
#       'id': '1Bk56nx76xE4nP01ZhDsPE',
#       'name': 'Jean-Ken Johnny',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Bk56nx76xE4nP01ZhDsPE'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5ZgtjJv323wnA438gazF23'},
#       'href': 'https://api.spotify.com/v1/artists/5ZgtjJv323wnA438gazF23',
#       'id': '5ZgtjJv323wnA438gazF23',
#       'name': 'KenKen',
#       'type': 'artist',
#       'uri': 'spotify:artist:5ZgtjJv323wnA438gazF23'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 296724,
#     'explicit': False,
#     'external_ids': {'isrc': 'JPB601800433'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1fPWFs6GjcSXknQKa6YKIh'},
#     'href': 'https://api.spotify.com/v1/tracks/1fPWFs6GjcSXknQKa6YKIh',
#     'id': '1fPWFs6GjcSXknQKa6YKIh',
#     'is_local': False,
#     'name': 'The Perfect World',
#     'popularity': 48,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a35b110c411fb9a411afd0ba304c7e78337764dc?cid=ae0dc287abd746f9bfc9fabb30966d0c',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1fPWFs6GjcSXknQKa6YKIh'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6bJCrLZcvsBMzve04BmgwS'},
#        'href': 'https://api.spotify.com/v1/artists/6bJCrLZcvsBMzve04BmgwS',
#        'id': '6bJCrLZcvsBMzve04BmgwS',
#        'name': 'Golden Vessel',
#        'type': 'artist',
#        'uri': 'spotify:artist:6bJCrLZcvsBMzve04BmgwS'}],
#      'available_markets': ['AD',
#       'AR',
#       'AT',
#       'BE',
#       'BG',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HN',
#       'HU',
#       'IE',
#       'IL',
#       'IS',
#       'IT',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'NI',
#       'NL',
#       'NO',
#       'PA',
#       'PE',
#       'PL',
#       'PT',
#       'PY',
#       'RO',
#       'SE',
#       'SK',
#       'SV',
#       'TN',
#       'US',
#       'UY',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1ArMlqQvnGBuwV1sBC5IOm'},
#      'href': 'https://api.spotify.com/v1/albums/1ArMlqQvnGBuwV1sBC5IOm',
#      'id': '1ArMlqQvnGBuwV1sBC5IOm',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/e3a61fccaf69176ad82d19e32f5cdb7d5daeb001',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/9c15a91f463be765f1f4488a0b843cf66fcbc2fd',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/f4a2348d05e671f85824205c4dff0cf2cbdc1a57',
#        'width': 64}],
#      'name': 'MOONSTONE (feat. Elkkle & Akurei)',
#      'release_date': '2018-11-30',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:1ArMlqQvnGBuwV1sBC5IOm'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6bJCrLZcvsBMzve04BmgwS'},
#       'href': 'https://api.spotify.com/v1/artists/6bJCrLZcvsBMzve04BmgwS',
#       'id': '6bJCrLZcvsBMzve04BmgwS',
#       'name': 'Golden Vessel',
#       'type': 'artist',
#       'uri': 'spotify:artist:6bJCrLZcvsBMzve04BmgwS'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5O3OUnaadL3aEVi5x6ImOl'},
#       'href': 'https://api.spotify.com/v1/artists/5O3OUnaadL3aEVi5x6ImOl',
#       'id': '5O3OUnaadL3aEVi5x6ImOl',
#       'name': 'Elkkle',
#       'type': 'artist',
#       'uri': 'spotify:artist:5O3OUnaadL3aEVi5x6ImOl'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/63H0n4HapCWFaX42LIfY37'},
#       'href': 'https://api.spotify.com/v1/artists/63H0n4HapCWFaX42LIfY37',
#       'id': '63H0n4HapCWFaX42LIfY37',
#       'name': 'Akurei',
#       'type': 'artist',
#       'uri': 'spotify:artist:63H0n4HapCWFaX42LIfY37'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HN',
#      'HU',
#      'IE',
#      'IL',
#      'IS',
#      'IT',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'NI',
#      'NL',
#      'NO',
#      'PA',
#      'PE',
#      'PL',
#      'PT',
#      'PY',
#      'RO',
#      'SE',
#      'SK',
#      'SV',
#      'TN',
#      'US',
#      'UY',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 195613,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUS11800329'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1yTY0ak3Zj8rt3UMyh1n4u'},
#     'href': 'https://api.spotify.com/v1/tracks/1yTY0ak3Zj8rt3UMyh1n4u',
#     'id': '1yTY0ak3Zj8rt3UMyh1n4u',
#     'is_local': False,
#     'name': 'MOONSTONE (feat. Elkkle & Akurei)',
#     'popularity': 42,
#     'preview_url': 'https://p.scdn.co/mp3-preview/f9c28f2f5851ebf9cc630abb344d9312ecabad0e?cid=ae0dc287abd746f9bfc9fabb30966d0c',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1yTY0ak3Zj8rt3UMyh1n4u'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3sGyf3EDcvQ4PB9AGIg84M'},
#        'href': 'https://api.spotify.com/v1/artists/3sGyf3EDcvQ4PB9AGIg84M',
#        'id': '3sGyf3EDcvQ4PB9AGIg84M',
#        'name': 'OSHUN',
#        'type': 'artist',
#        'uri': 'spotify:artist:3sGyf3EDcvQ4PB9AGIg84M'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5YHDy8wLZRaVKH8enUQHAE'},
#      'href': 'https://api.spotify.com/v1/albums/5YHDy8wLZRaVKH8enUQHAE',
#      'id': '5YHDy8wLZRaVKH8enUQHAE',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/a77d00d0de82e7bf40fbcb08ddff71627fc1ab1b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/7ae195ac35a3aa412ef2908f46e10d91b430ad12',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/5ea6662d6ca0837f7b4d0cd7a8289334dbad4f0b',
#        'width': 64}],
#      'name': 'bittersweet vol. 1',
#      'release_date': '2018-04-06',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:5YHDy8wLZRaVKH8enUQHAE'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3sGyf3EDcvQ4PB9AGIg84M'},
#       'href': 'https://api.spotify.com/v1/artists/3sGyf3EDcvQ4PB9AGIg84M',
#       'id': '3sGyf3EDcvQ4PB9AGIg84M',
#       'name': 'OSHUN',
#       'type': 'artist',
#       'uri': 'spotify:artist:3sGyf3EDcvQ4PB9AGIg84M'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 237893,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZ5AB1890715'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2iEyH6VId86bdxXduzFWND'},
#     'href': 'https://api.spotify.com/v1/tracks/2iEyH6VId86bdxXduzFWND',
#     'id': '2iEyH6VId86bdxXduzFWND',
#     'is_local': False,
#     'name': 'Solar Plexus',
#     'popularity': 45,
#     'preview_url': 'https://p.scdn.co/mp3-preview/823305bfcba0abafc38fb8b0ffcb3cd82a713cbb?cid=ae0dc287abd746f9bfc9fabb30966d0c',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:2iEyH6VId86bdxXduzFWND'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2abf5MCGiDUvtFfBU3tHw8'},
#        'href': 'https://api.spotify.com/v1/artists/2abf5MCGiDUvtFfBU3tHw8',
#        'id': '2abf5MCGiDUvtFfBU3tHw8',
#        'name': 'By Lotus',
#        'type': 'artist',
#        'uri': 'spotify:artist:2abf5MCGiDUvtFfBU3tHw8'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1ix2XBRA2QHKzwqmAbfUGx'},
#      'href': 'https://api.spotify.com/v1/albums/1ix2XBRA2QHKzwqmAbfUGx',
#      'id': '1ix2XBRA2QHKzwqmAbfUGx',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/4b56cce965dc37d965b8364f505449809de1105f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/7f85e4016526052c1e7b8eb6602e87f0a0388ce5',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/0134272f326ccc256bca16746fb02da46fc460ea',
#        'width': 64}],
#      'name': 'To Be Still',
#      'release_date': '2018-01-19',
#      'release_date_precision': 'day',
#      'total_tracks': 8,
#      'type': 'album',
#      'uri': 'spotify:album:1ix2XBRA2QHKzwqmAbfUGx'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2abf5MCGiDUvtFfBU3tHw8'},
#       'href': 'https://api.spotify.com/v1/artists/2abf5MCGiDUvtFfBU3tHw8',
#       'id': '2abf5MCGiDUvtFfBU3tHw8',
#       'name': 'By Lotus',
#       'type': 'artist',
#       'uri': 'spotify:artist:2abf5MCGiDUvtFfBU3tHw8'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 227700,
#     'explicit': False,
#     'external_ids': {'isrc': 'SE5Q51800035'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3oGxh58Be8qktgLuFqsFGb'},
#     'href': 'https://api.spotify.com/v1/tracks/3oGxh58Be8qktgLuFqsFGb',
#     'id': '3oGxh58Be8qktgLuFqsFGb',
#     'is_local': False,
#     'name': 'To Be Still',
#     'popularity': 43,
#     'preview_url': 'https://p.scdn.co/mp3-preview/5c993b32a651fdc7e3836a8b67154c539f3e068a?cid=ae0dc287abd746f9bfc9fabb30966d0c',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3oGxh58Be8qktgLuFqsFGb'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/65FPMBREZBLfEDpkHlm8sS'},
#        'href': 'https://api.spotify.com/v1/artists/65FPMBREZBLfEDpkHlm8sS',
#        'id': '65FPMBREZBLfEDpkHlm8sS',
#        'name': 'Alex Siegel',
#        'type': 'artist',
#        'uri': 'spotify:artist:65FPMBREZBLfEDpkHlm8sS'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0fotwiIbirxfzOIqBguzg4'},
#      'href': 'https://api.spotify.com/v1/albums/0fotwiIbirxfzOIqBguzg4',
#      'id': '0fotwiIbirxfzOIqBguzg4',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/bf3528933e27f04c19325516d7ac642616894aff',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/1a20057862503b05ac4def37d0f9bc606a707759',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/066aa831018ec772bfea5064da458c3cbd0640ae',
#        'width': 64}],
#      'name': 'Lonely Days',
#      'release_date': '2018-09-21',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:0fotwiIbirxfzOIqBguzg4'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/65FPMBREZBLfEDpkHlm8sS'},
#       'href': 'https://api.spotify.com/v1/artists/65FPMBREZBLfEDpkHlm8sS',
#       'id': '65FPMBREZBLfEDpkHlm8sS',
#       'name': 'Alex Siegel',
#       'type': 'artist',
#       'uri': 'spotify:artist:65FPMBREZBLfEDpkHlm8sS'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 280000,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBKPL1819553'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3qLqAlhe4WKDim35hYeSS9'},
#     'href': 'https://api.spotify.com/v1/tracks/3qLqAlhe4WKDim35hYeSS9',
#     'id': '3qLqAlhe4WKDim35hYeSS9',
#     'is_local': False,
#     'name': 'Lonely Days',
#     'popularity': 40,
#     'preview_url': 'https://p.scdn.co/mp3-preview/fa4aaa9c0bec0c5d89eeefa5502d8f5a67dfd994?cid=ae0dc287abd746f9bfc9fabb30966d0c',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3qLqAlhe4WKDim35hYeSS9'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6w9ToX5slZ4uIdmD17hJ3c'},
#        'href': 'https://api.spotify.com/v1/artists/6w9ToX5slZ4uIdmD17hJ3c',
#        'id': '6w9ToX5slZ4uIdmD17hJ3c',
#        'name': 'Bryant Myers',
#        'type': 'artist',
#        'uri': 'spotify:artist:6w9ToX5slZ4uIdmD17hJ3c'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0AAxqrygloVXEathVtYauj'},
#      'href': 'https://api.spotify.com/v1/albums/0AAxqrygloVXEathVtYauj',
#      'id': '0AAxqrygloVXEathVtYauj',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/b748929a2eea8805558d1b431d6cd17cda794697',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/d689c9677d1e67e9eae8319bffce61af0fe04b05',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/0b00ee7c46c219d6efcfb2c6bac50d176f5b8d36',
#        'width': 64}],
#      'name': 'La Oscuridad',
#      'release_date': '2018-07-27',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:0AAxqrygloVXEathVtYauj'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6w9ToX5slZ4uIdmD17hJ3c'},
#       'href': 'https://api.spotify.com/v1/artists/6w9ToX5slZ4uIdmD17hJ3c',
#       'id': '6w9ToX5slZ4uIdmD17hJ3c',
#       'name': 'Bryant Myers',
# ...
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6qoFU4n57agQlV41x1UjyT'},
#      'href': 'https://api.spotify.com/v1/albums/6qoFU4n57agQlV41x1UjyT',
#      'id': '6qoFU4n57agQlV41x1UjyT',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/32520a658f2d84095d7970c072a2aa471219eff8',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/a9cc522f936f7e771f5332661391449d5d09d6f8',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/a1ea9482d387da0a49934db80ce8a621816bc4b5',
#        'width': 64}],
#      'name': 'Hunger Games 3',
#      'release_date': '2018-12-07',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:6qoFU4n57agQlV41x1UjyT'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/45TgXXqMDdF8BkjA83OM7z'},
#       'href': 'https://api.spotify.com/v1/artists/45TgXXqMDdF8BkjA83OM7z',
#       'id': '45TgXXqMDdF8BkjA83OM7z',
#       'name': 'Rod Wave',
#       'type': 'artist',
#       'uri': 'spotify:artist:45TgXXqMDdF8BkjA83OM7z'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 145297,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUYG1230303'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3FO8HnvvJsURi9dnxTtqBY'},
#     'href': 'https://api.spotify.com/v1/tracks/3FO8HnvvJsURi9dnxTtqBY',
#     'id': '3FO8HnvvJsURi9dnxTtqBY',
#     'is_local': False,
#     'name': "Can't Sleep",
#     'popularity': 38,
#     'preview_url': 'https://p.scdn.co/mp3-preview/86477f31a8756ff7b1a5ab2f30801c3343cbe103?cid=ae0dc287abd746f9bfc9fabb30966d0c',
#     'track_number': 12,
#     'type': 'track',
#     'uri': 'spotify:track:3FO8HnvvJsURi9dnxTtqBY'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3jsyANBBy6gOZUSQhiGclx'},
#        'href': 'https://api.spotify.com/v1/artists/3jsyANBBy6gOZUSQhiGclx',
#        'id': '3jsyANBBy6gOZUSQhiGclx',
#        'name': 'Ninja Sex Party',
#        'type': 'artist',
#        'uri': 'spotify:artist:3jsyANBBy6gOZUSQhiGclx'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6qzEz6LqVHfLANKqqgrmfE'},
#      'href': 'https://api.spotify.com/v1/albums/6qzEz6LqVHfLANKqqgrmfE',
#      'id': '6qzEz6LqVHfLANKqqgrmfE',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/f77e740d7e48947dfa4e16e22e36000ef3adb6b8',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/3ecb2d5808359635c36c0e5c1652b5039db87905',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/de560b5aa0be38340a39b60481ff5231bd8616bd',
#        'width': 64}],
#      'name': 'Cool Patrol',
#      'release_date': '2018-08-17',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:6qzEz6LqVHfLANKqqgrmfE'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3jsyANBBy6gOZUSQhiGclx'},
#       'href': 'https://api.spotify.com/v1/artists/3jsyANBBy6gOZUSQhiGclx',
#       'id': '3jsyANBBy6gOZUSQhiGclx',
#       'name': 'Ninja Sex Party',
#       'type': 'artist',
#       'uri': 'spotify:artist:3jsyANBBy6gOZUSQhiGclx'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 169103,
#     'explicit': True,
#     'external_ids': {'isrc': 'usdy41860960'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4BAFAC8Q5I5dLrcGew7BAe'},
#     'href': 'https://api.spotify.com/v1/tracks/4BAFAC8Q5I5dLrcGew7BAe',
#     'id': '4BAFAC8Q5I5dLrcGew7BAe',
#     'is_local': False,
#     'name': 'Courtship of the Mermaid',
#     'popularity': 42,
#     'preview_url': 'https://p.scdn.co/mp3-preview/7583f986debd8de1ceb63d4dc1cf64a00ce71bf8?cid=ae0dc287abd746f9bfc9fabb30966d0c',
#     'track_number': 12,
#     'type': 'track',
#     'uri': 'spotify:track:4BAFAC8Q5I5dLrcGew7BAe'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3WrFJ7ztbogyGnTHbHJFl2'},
#        'href': 'https://api.spotify.com/v1/artists/3WrFJ7ztbogyGnTHbHJFl2',
#        'id': '3WrFJ7ztbogyGnTHbHJFl2',
#        'name': 'The Beatles',
#        'type': 'artist',
#        'uri': 'spotify:artist:3WrFJ7ztbogyGnTHbHJFl2'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1WMVvswNzB9i2UMh9svso5'},
#      'href': 'https://api.spotify.com/v1/albums/1WMVvswNzB9i2UMh9svso5',
#      'id': '1WMVvswNzB9i2UMh9svso5',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/c8e438a7b5cfbceef51af4753881ab9ed1ed895c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/1892fe468153bf6f618fbb350afdbc7d683b92cb',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/f6e12b2ef70abf43d110e5c79810655c7c3fae98',
#        'width': 64}],
#      'name': 'The Beatles',
#      'release_date': '2018-11-09',
#      'release_date_precision': 'day',
#      'total_tracks': 107,
#      'type': 'album',
#      'uri': 'spotify:album:1WMVvswNzB9i2UMh9svso5'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3WrFJ7ztbogyGnTHbHJFl2'},
#       'href': 'https://api.spotify.com/v1/artists/3WrFJ7ztbogyGnTHbHJFl2',
#       'id': '3WrFJ7ztbogyGnTHbHJFl2',
#       'name': 'The Beatles',
#       'type': 'artist',
#       'uri': 'spotify:artist:3WrFJ7ztbogyGnTHbHJFl2'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 101733,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBUM71802716'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6CD4ZmCgYyiECTOWjm5LqC'},
#     'href': 'https://api.spotify.com/v1/tracks/6CD4ZmCgYyiECTOWjm5LqC',
#     'id': '6CD4ZmCgYyiECTOWjm5LqC',
#     'is_local': False,
#     'name': "Why Don't We Do It In The Road? - 2018 Mix",
#     'popularity': 46,
#     'preview_url': None,
#     'track_number': 15,
#     'type': 'track',
#     'uri': 'spotify:track:6CD4ZmCgYyiECTOWjm5LqC'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LB6JS8nrAl1EPBOLBlcIC'},
#        'href': 'https://api.spotify.com/v1/artists/0LB6JS8nrAl1EPBOLBlcIC',
#        'id': '0LB6JS8nrAl1EPBOLBlcIC',
#        'name': 'LaShawn the Lyricist',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LB6JS8nrAl1EPBOLBlcIC'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4vsvXN1ctJneIpxM94OOfD'},
#      'href': 'https://api.spotify.com/v1/albums/4vsvXN1ctJneIpxM94OOfD',
#      'id': '4vsvXN1ctJneIpxM94OOfD',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/b44e1acb97cc361ca2bc8aea8f576ff43817f05c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/11eac8dc35dcb65b8b5edcb6fdce8dacc53d3b6d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/6f142f9a75868f17b2384d50428757d3a207ced3',
#        'width': 64}],
#      'name': 'Jealous',
#      'release_date': '2018-07-03',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:4vsvXN1ctJneIpxM94OOfD'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LB6JS8nrAl1EPBOLBlcIC'},
#       'href': 'https://api.spotify.com/v1/artists/0LB6JS8nrAl1EPBOLBlcIC',
#       'id': '0LB6JS8nrAl1EPBOLBlcIC',
#       'name': 'LaShawn the Lyricist',
#       'type': 'artist',
#       'uri': 'spotify:artist:0LB6JS8nrAl1EPBOLBlcIC'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7C2C3cso70sg3rZWiNBlSn'},
#       'href': 'https://api.spotify.com/v1/artists/7C2C3cso70sg3rZWiNBlSn',
#       'id': '7C2C3cso70sg3rZWiNBlSn',
#       'name': 'Lil Fendy',
#       'type': 'artist',
#       'uri': 'spotify:artist:7C2C3cso70sg3rZWiNBlSn'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 118003,
#     'explicit': True,
#     'external_ids': {'isrc': 'QZDA51876110'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0Z4D6ageAQy7hzaqUdH9II'},
#     'href': 'https://api.spotify.com/v1/tracks/0Z4D6ageAQy7hzaqUdH9II',
#     'id': '0Z4D6ageAQy7hzaqUdH9II',
#     'is_local': False,
#     'name': 'Jealous',
#     'popularity': 38,
#     'preview_url': 'https://p.scdn.co/mp3-preview/c438e6b68882a36d9fdb2e93866eacc33dae8ce8?cid=ae0dc287abd746f9bfc9fabb30966d0c',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0Z4D6ageAQy7hzaqUdH9II'}],
#   'limit': 50,
#   'next': 'https://api.spotify.com/v1/search?query=year%3A2018&type=track&offset=10000&limit=50',
#   'offset': 9950,
#   'previous': 'https://api.spotify.com/v1/search?query=year%3A2018&type=track&offset=9900&limit=50',
#   'total': 6060235}}

# %%
import time
import pandas as pd
import numpy as np
import re
import spotipy
import sys
import os
import json
import pprint
from __future__ import print_function    # (at top of module)
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy.oauth2 as oauth2
import spotipy.util as util

# %%
cid ="ae0dc287abd746f9bfc9fabb30966d0c" 
secret = "40c2e16da28c49e1839219c99e697910"
username= "Mohamad Eldebek"

client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)


results = sp.search(q='kanye', limit=20)
for i, t in enumerate(results['tracks']['items']):
    print(' ', i, t['name'])

# %%
len(sys.argv)

# %%
' '.join(sys.argv[:])

# %%
artist_name = 'weezer'

results = sp.search(q=artist_name, limit=50)
tids = []
for i, t in enumerate(results['tracks']['items']):
    print(' ', i, t['name'])
    tids.append(t['uri'])

start = time.time()
features = sp.audio_features(tids)
delta = time.time() - start
for feature in features:
    print(json.dumps(feature, indent=4))
    print()
    analysis = sp._get(feature['analysis_url'])
    print(json.dumps(analysis, indent=4))
    print()
print ("features retrieved in %.2f seconds" % (delta,))

# %%
# The popularity of a track is a value between 0 and 100, with 100 being the most popular. 
# The popularity is calculated by algorithm and is based, in the most part, on the total number of plays 
# the track has had and how recent those plays are.
# Generally speaking, songs that are being played a lot now will have a higher popularity than songs that were 
# played a lot in the past. Duplicate tracks (e.g. the same track from a single and an album) are rated independently. 
# Artist and album popularity is derived mathematically from track popularity. Note that the popularity value may 
# lag actual popularity by a few days: the value is not updated in real time.

# %%
cid ="ae0dc287abd746f9bfc9fabb30966d0c" 
secret = "40c2e16da28c49e1839219c99e697910"
username= "Mohamad Eldebek"

client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)

sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

YWUwZGMyODdhYmQ3NDZmOWJmYzlmYWJiMzA5NjZkMGM6NDBjMmUxNmRhMjhjNDllMTgzOTIxOWM5OWU2OTc5MTAK

https://accounts.spotify.com/authorize
    
    
model = spotipy.Spotify(client_credentials_manager=client_cred_manager)
scope = 'user-library-read playlist-read-private'
#token = "Bearer BQBHbEieVIBtDz5QcD3M6LxfWXcscBYd7ZzStDjP_3wKHkEFjY4QqFV-82EcU-wNvBo_Fnawc7JMx9KDLx1WdaWj2gojr5RGZguzsyEPg5RkkBPLDbnum850dZ4e_xRu41DOWsfZWNBq1tlfzDkRF1j3SgPAs-0zFut3WCoj&refresh_token=AQCPILw9Y6szk_KjqSVIHueizz-AU4iEPZ2SnkxLhTjtlPgI3l0eh8As9tEcmq3RJoqEMYceU71bA-jeUeYWnUOo5WZCNgq9IQUB9CqPR0OwFwJUInJFNVuncqKeU6yddAY"
token = curl -H "Authorization: Basic ZjM...zE=" -d grant_type=authorization_code -d code=MQCbtKe...44KN -d redirect_uri=https%3A%2F%2Fwww.foo.com%2Fauth https://accounts.spotify.com/api/token

token = util.prompt_for_user_token(username, scope, client_id=cid, client_secret=secret, redirect_uri= "http%3A%2F%2Fmeldebek.com%2Fcallback%2F")
if token:
    model = spotipy.Spotify(auth=token)
else:
    print("unable to get token for:", username)

# %%
credentials = oauth2.SpotifyClientCredentials(
        client_id=cid,
        client_secret=secret)

token = credentials.get_access_token()
spotify = spotipy.Spotify(auth=token)

# Main definition - constants
menu_actions  = {}

def main_menu():
    os.system('clear')
    
    print ("Welcome,\n")
    print ("Please choose the menu you want to start:")
    print ("1. Track")
    print ("2. Artist")
    print ("3. Album")
    print ("4. User")
    print ("\n0. Quit")
    choice = raw_input(" >>  ")
    print ("choice")
    exec_menu(choice, '0')
 
    return


# TRACK MENU
def track_menu():
    print ("TRACK MENU\n")
    print ("1. General Info")
    print ("2. Audio Features")
    print ("3. Audio Analysis")
    print ("9. Back")
    print ("0. Quit")
    choice = raw_input(" >>  ")
    exec_menu(choice, '1')
    return


def track_info():
    os.system('clear')
    track = raw_input(" >> Track name: ")
    results = spotify.search(q=track, limit=1)
    pprint.pprint(results)
    press_to_go_back(1)


def track_features():
    os.system('clear')
    track = raw_input(" >> Track name: ")
    results = spotify.search(q=track, limit=1)
    track_id = results['tracks']['items'][0]['id']
    pprint.pprint(spotify.audio_features([track_id]))
    press_to_go_back(1)


def track_analysis():
    os.system('clear')
    track = raw_input(" >> Track name: ")
    results = spotify.search(q=track, limit=1)
    track_id = results['tracks']['items'][0]['id']
    pprint.pprint(spotify.audio_analysis(track_id))
    press_to_go_back(1)
    
 # ARTIST MENU
def artist_menu():
    print ("ARTIST MENU\n")
    print ("1. General Info")
    print ("2. Albums")
    print ("3. Top Tracks")
    print ("4. Related Artists")
    print ("9. Back")
    print ("0. Quit" )
    choice = raw_input(" >>  ")
    exec_menu(choice, '2')
    return


def artist_info():
    os.system('clear')
    artist = raw_input(" >> Artist name: ")
    results = spotify.search(q=artist, limit=1, type='artist')
    pprint.pprint(results)
    press_to_go_back(2)


def artist_albums():
    os.system('clear')
    artist = raw_input(" >> Artist name: ")
    results = spotify.search(q=artist, limit=1, type='artist')
    artist_id = results['artists']['items'][0]['id']
    pprint.pprint(spotify.artist_albums(artist_id, album_type='album'))
    press_to_go_back(2)


def artist_top_tracks():
    os.system('clear')
    artist = raw_input(" >> Artist name: ")
    results = spotify.search(q=artist, limit=1, type='artist')
    artist_id = results['artists']['items'][0]['id']
    pprint.pprint(spotify.artist_top_tracks(artist_id, country='PT'))
    press_to_go_back(2)


def artist_related_artists():
    os.system('clear')
    artist = raw_input(" >> Artist name: ")
    results = spotify.search(q=artist, limit=1, type='artist')
    artist_id = results['artists']['items'][0]['id']
    pprint.pprint(spotify.artist_related_artists(artist_id))
    press_to_go_back(2)


# ALBUM MENU
def album_menu():
    print ("ALBUM MENU\n")
    print ("1. General Info")
    print ("2. Album Tracks")
    print ("9. Back")
    print ("0. Quit") 
    choice = raw_input(" >>  ")
    exec_menu(choice, '3')
    return


def album_info():
    os.system('clear')
    album = raw_input(" >> Album name: ")
    results = spotify.search(q=album, limit=1, type='album')
    pprint.pprint(results)
    press_to_go_back(3)


def album_tracks():
    os.system('clear')
    album = raw_input(" >> Album name: ")
    results = spotify.search(q=album, limit=1, type='album')
    album_id = results['albums']['items'][0]['id']
    pprint.pprint(spotify.album_tracks(album_id))
    press_to_go_back(3)


# USER MENU
def user_menu():
    print ("USER MENU\n")
    print ("1. Top Tracks")
    print ("2. Top Artists")
    print ("3. Recently Played Tracks")
    print ("4. Reset User")
    print ("9. Back")
    print ("0. Quit\n" )
    choice = raw_input(" >>  ")
    exec_menu(choice, '4')
    return


def user_top_tracks():
    os.system('clear')
    limit = 50 # default limit = 20
    username = 'top'
    scope = 'user-top-read'
    token = util.prompt_for_user_token(username, scope,client_id=CLIENT_ID,client_secret=CLIENT_SECRET,redirect_uri=REDIRECT_URI)
    spotify = spotipy.Spotify(auth=token)
    results = spotify.current_user_top_tracks(limit=limit, time_range='long_term')
    # pprint.pprint(results)

    for i in range(0, limit):
        print str(i+1) + ". " + results['items'][i]['artists'][0]['name'] + ' - ' + results['items'][i]['name']
    press_to_go_back(4)


def user_top_artists():
    os.system('clear')
    limit = 50
    username = 'top'
    scope = 'user-top-read'
    token = util.prompt_for_user_token(username, scope,client_id=CLIENT_ID,client_secret=CLIENT_SECRET,redirect_uri=REDIRECT_URI)
    spotify = spotipy.Spotify(auth=token)
    results = spotify.current_user_top_artists(limit=limit, time_range='long_term')
    # pprint.pprint(results)

    for i in range(0, len(results['items'])):
        print str(i+1) + ". " + results['items'][i]['name']
    press_to_go_back(4)


def user_recent_tracks():
    os.system('clear')
    limit = 20
    username = 'recent'
    scope = 'user-read-recently-played'
    token = util.prompt_for_user_token(username, scope,client_id=CLIENT_ID,client_secret=CLIENT_SECRET,redirect_uri=REDIRECT_URI)
    spotify = spotipy.Spotify(auth=token)
    results = spotify.current_user_recently_played(limit=limit)
    # pprint.pprint(results)

    for i in range(0, limit):
        print results['items'][i]['track']['artists'][0]['name'] + ' - ' + results['items'][i]['track']['name']
    press_to_go_back(4)


def reset_user():
    os.system('clear')
    dir_name = os.path.dirname(os.path.realpath(__file__))
    file_list = os.listdir(dir_name)
    flag = 0

    for item in file_list:
        if item.startswith('.cache'):
            os.remove(os.path.join(dir_name, item))
            flag = 1
    
    if flag:
        print "User(s) removed with success!"
    press_to_go_back(4)


def exec_menu(choice, menu_id):
    os.system('clear')
    ch = choice.lower()
    if ch == '':
        menu_actions['main_menu']()
    else:
        try:
            menu_actions[menu_id][ch]()
        except KeyError:
            print "Invalid selection, please try again.\n"
            menu_actions[menu_id]['menu']()
    return


def press_to_go_back(menu_id):
    raw_input(">> Press to go back to menu")
    os.system('clear')
    menu_actions[str(menu_id)]['menu']()


# Back to main menu
def back():
    menu_actions['0']['menu']()

 # Exit program
def exit():
    sys.exit()


# Menu definition
menu_actions = {
    '0' : {
        'menu': main_menu,
        '1': track_menu,
        '2': artist_menu,
        '3': album_menu,
        '4': user_menu,
        '9': back,
        '0': exit,
    },
    '1' : {
        'menu': track_menu,
        '1': track_info,
        '2': track_features,
        '3': track_analysis,
        '9': back,
        '0': exit,
    },
    '2' : {
        'menu': artist_menu,
        '1': artist_info,
        '2': artist_albums,
        '3': artist_top_tracks,
        '4': artist_related_artists,
        '9': back,
        '0': exit,
    },
    '3' : {
        'menu': album_menu,
        '1': album_info,
        '2': album_tracks,
        '9': back,
        '0': exit,
    },
    '4' : {
        'menu': user_menu,
        '1': user_top_tracks,
        '2': user_top_artists,
        '3': user_recent_tracks,
        '4': reset_user,
        '9': back,
        '0': exit,
    },
}


if __name__ == '__main__':
    main_menu()
# Out:
#   File "<ipython-input-18-99ab7f4ffa52>", line 169
#     print str(i+1) + ". " + results['items'][i]['artists'][0]['name'] + ' - ' + results['items'][i]['name']
#             ^
# SyntaxError: invalid syntax
